# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random 

threshold = 10 ** -6
each_word_count = Counter(int_words)
total_word_count = len(int_words)
frequency_word = { word : count/total_word_count for word, count in each_word_count.items() }
probability_words = { word: ( 1-np.sqrt( threshold / frequency_word[word] )) for word, count in each_word_count.items()}
train_words = [ word for word in int_words if probability_words[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    import random
    R = random.randint(1, window_size+1)
    start = idx - R if idx - R > 0 else 0
    stop = idx + R if idx + R < len(words) else len(words)
    return list(set(words[start:idx-1] + words[idx+1:stop]))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding],
                      stddev=0.01))
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab, name='softmax_loss')
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 4.9057 0.3182 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 4.8056 0.3164 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 4.8657 0.3105 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 4.8912 0.3132 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 4.8996 0.3288 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.8408 0.3276 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.8283 0.3166 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.8000 0.3155 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.8373 0.3317 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.7440 0.3321 sec/batch
# Nearest to will: inhabitants, sentinels, antlia, minted, fail, stash, apsaras, restaurant,
# Nearest to and: currency, hotly, genetically, wraith, taz, force, yf, presumably,
# Nearest to which: with, doctors, innings, use, without, rapping, now, defined,
# Nearest to state: tends, petitioning, retreated, produced, reclaiming, turpin, grave, plausibly,
# Nearest to over: dear, auxerre, cristo, juvenile, eschatology, downland, dictate, better,
# Nearest to on: chemical, amount, mistaken, pathfinder, darkness, lautrec, funk, chanted,
# Nearest to this: injera, providencia, given, prevalent, distributes, knife, service, to,
# Nearest to four: worst, answered, audio, meltdown, powerplants, ibex, kurukshetra, oscillating,
# Nearest to bible: cmd, productive, armstrong, adderall, bunk, antiwar, marcos, ideographic,
# Nearest to articles: trade, endowment, analytic, improvisational, pell, smiles, gradually, mover,
# Nearest to hold: stallman, bequeathed, muratorian, confidence, longitudinally, isdb, aspirin, simo,
# Nearest to brother: messiah, magistracy, baines, croce, lasor, verses, defiled, hyena,
# Nearest to creation: golda, hosts, render, distasteful, phagocytic, outdoors, sati, mb,
# Nearest to bbc: dealerships, abbr, coolidge, gion, riccati, backwards, covey, findslot,
# Nearest to governor: kees, shocks, beauty, eicher, chronicling, fencer, pds, ratisbon,
# Nearest to numerous: matthias, tracts, hierarchy, barons, showed, baker, classify, hartley,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.6919 0.3411 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.6691 0.3329 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7066 0.3107 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.6893 0.3114 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.6366 0.3208 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.5933 0.3106 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.5914 0.3143 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.5950 0.3137 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.5419 0.3232 sec/batch
# Epoch 2/10 Iteration: 2000 Avg. Training loss: 4.5641 0.1480 sec/batch
# Nearest to will: sentinels, restaurant, fail, beautiful, antlia, inhabitants, stash, papa,
# Nearest to and: hotly, contaminants, wraith, purported, currency, taz, yf, facility,
# Nearest to which: doctors, rapping, ibizan, innings, blvd, bigg, settlements, mounted,
# Nearest to state: petitioning, retreated, tends, reclaiming, plausibly, produced, teamsters, synaptic,
# Nearest to over: auxerre, juvenile, dear, eschatology, downland, disagreed, dictate, cristo,
# Nearest to on: mistaken, lautrec, pathfinder, chemical, imitates, darkness, marketers, squarely,
# Nearest to this: injera, motorized, knife, providencia, prevalent, automatic, leased, concludes,
# Nearest to four: worst, answered, strictly, powerplants, norm, elects, grimmett, commodities,
# Nearest to bible: cmd, productive, armstrong, adderall, antiwar, ideographic, bunk, marcos,
# Nearest to articles: endowment, analytic, trade, pell, improvisational, sufficed, mover, medici,
# Nearest to hold: stallman, bequeathed, confidence, simo, reformist, contexts, muratorian, hydrofoil,
# Nearest to brother: messiah, magistracy, verses, baines, exceedingly, croce, illustrator, markers,
# Nearest to creation: outdoors, hosts, distasteful, render, golda, nepal, covering, increase,
# Nearest to bbc: dealerships, gion, abbr, coolidge, postcards, riccati, adapt, royston,
# Nearest to governor: kees, shocks, beauty, chronicling, pds, improved, thunderbirds, eicher,
# Nearest to numerous: matthias, tracts, hierarchy, barons, cities, baker, textile, specialization,
# Epoch 2/10 Iteration: 2100 Avg. Training loss: 4.4427 0.3292 sec/batch
# Epoch 2/10 Iteration: 2200 Avg. Training loss: 4.4165 0.3227 sec/batch
# Epoch 2/10 Iteration: 2300 Avg. Training loss: 4.4503 0.3198 sec/batch
# Epoch 2/10 Iteration: 2400 Avg. Training loss: 4.4394 0.3224 sec/batch
# Epoch 2/10 Iteration: 2500 Avg. Training loss: 4.4283 0.3265 sec/batch
# Epoch 2/10 Iteration: 2600 Avg. Training loss: 4.4023 0.3153 sec/batch
# Epoch 2/10 Iteration: 2700 Avg. Training loss: 4.3921 0.3159 sec/batch
# Epoch 2/10 Iteration: 2800 Avg. Training loss: 4.4132 0.3203 sec/batch
# Epoch 2/10 Iteration: 2900 Avg. Training loss: 4.4246 0.5274 sec/batch
# Epoch 2/10 Iteration: 3000 Avg. Training loss: 4.3872 0.5394 sec/batch
# Nearest to will: sentinels, cryptozoologists, lxx, fail, restaurant, antlia, stash, apsaras,
# Nearest to and: hotly, contaminants, purported, yf, taz, wraith, crystals, stardust,
# Nearest to which: doctors, rapping, ibizan, oxus, freethought, bigg, decss, ditched,
# Nearest to state: petitioning, plausibly, retreated, synaptic, udp, reclaiming, envious, produced,
# Nearest to over: auxerre, downland, unb, dear, simpler, juvenile, spatial, drafts,
# Nearest to on: lautrec, marketers, mistaken, pathfinder, imitates, trifling, viking, hoffa,
# Nearest to this: motorized, injera, concludes, prevalent, providencia, automatic, knife, vires,
# Nearest to four: worst, answered, powerplants, strictly, oscillating, elects, grimmett, vanier,
# Nearest to bible: cmd, productive, pictorial, armstrong, bunk, adderall, ideographic, alltel,
# Nearest to articles: endowment, analytic, sufficed, trade, pell, beheld, phaenomena, medici,
# Nearest to hold: stallman, bequeathed, muratorian, carvey, confidence, simo, contexts, cooperstown,
# Nearest to brother: magistracy, baines, messiah, illustrator, defiled, croce, ariane, exceedingly,
# Nearest to creation: distasteful, hosts, golda, outdoors, render, secessionist, utterances, nepal,
# Nearest to bbc: dealerships, abbr, coolidge, riccati, lexicon, postcards, royston, gion,
# Nearest to governor: kees, chronicling, beauty, shocks, pedro, eicher, woodward, thunderbirds,
# Nearest to numerous: tracts, matthias, barons, cities, abd, hierarchy, specialization, grasps,
# Epoch 2/10 Iteration: 3100 Avg. Training loss: 4.4016 0.4339 sec/batch
# Epoch 2/10 Iteration: 3200 Avg. Training loss: 4.4286 0.3422 sec/batch
# Epoch 2/10 Iteration: 3300 Avg. Training loss: 4.4166 0.3183 sec/batch
# Epoch 2/10 Iteration: 3400 Avg. Training loss: 4.4416 0.3024 sec/batch
# Epoch 2/10 Iteration: 3500 Avg. Training loss: 4.3819 0.2921 sec/batch
# Epoch 2/10 Iteration: 3600 Avg. Training loss: 4.3948 0.3022 sec/batch
# Epoch 2/10 Iteration: 3700 Avg. Training loss: 4.3641 0.2996 sec/batch
# Epoch 2/10 Iteration: 3800 Avg. Training loss: 4.4134 0.3004 sec/batch
# Epoch 2/10 Iteration: 3900 Avg. Training loss: 4.3807 0.2953 sec/batch
# Epoch 3/10 Iteration: 4000 Avg. Training loss: 4.3369 0.3116 sec/batch
# Nearest to will: sentinels, lxx, cryptozoologists, antlia, fail, stash, restaurant, apsaras,
# Nearest to and: hotly, contaminants, purported, stardust, yf, wraith, taz, valuing,
# Nearest to which: doctors, ibizan, oxus, decss, homologous, bigg, rapping, darkly,
# Nearest to state: petitioning, retreated, kristianstad, udp, synaptic, plausibly, reclaiming, teamsters,
# Nearest to over: unb, auxerre, juvenile, downland, simpler, disagreed, lownds, drafts,
# Nearest to on: lautrec, marketers, pathfinder, trifling, mistaken, kapit, imitates, viking,
# Nearest to this: motorized, injera, prevalent, concludes, providencia, airspeeds, zigzag, knife,
# Nearest to four: worst, powerplants, commodities, grimmett, answered, vanier, elects, interleaved,
# Nearest to bible: cmd, bunk, pictorial, adderall, productive, ideographic, armstrong, facilitation,
# Nearest to articles: endowment, analytic, beheld, sufficed, pell, doren, trade, improvisational,
# Nearest to hold: stallman, bequeathed, carvey, muratorian, solidifies, lightened, confidence, simo,
# Nearest to brother: magistracy, defiled, illustrator, croce, baines, ariane, sammy, messiah,
# Nearest to creation: distasteful, golda, render, hosts, secessionist, outdoors, phagocytic, nepal,
# Nearest to bbc: abbr, dealerships, coolidge, riccati, postcards, gion, zuid, vest,
# Nearest to governor: kees, eicher, pedro, ratisbon, chronicling, woodward, beauty, shocks,
# Nearest to numerous: tracts, cities, matthias, barons, hierarchy, abd, grasps, convict,
# Epoch 3/10 Iteration: 4100 Avg. Training loss: 4.2853 0.3317 sec/batch
# Epoch 3/10 Iteration: 4200 Avg. Training loss: 4.3136 0.3320 sec/batch
# Epoch 3/10 Iteration: 4300 Avg. Training loss: 4.3165 0.3117 sec/batch
# Epoch 3/10 Iteration: 4400 Avg. Training loss: 4.2975 0.3016 sec/batch
# Epoch 3/10 Iteration: 4500 Avg. Training loss: 4.3005 0.3014 sec/batch
# Epoch 3/10 Iteration: 4600 Avg. Training loss: 4.2709 0.3040 sec/batch
# Epoch 3/10 Iteration: 4700 Avg. Training loss: 4.2979 0.3028 sec/batch
# Epoch 3/10 Iteration: 4800 Avg. Training loss: 4.2900 0.2659 sec/batch
# Epoch 3/10 Iteration: 4900 Avg. Training loss: 4.2851 0.3350 sec/batch
# Epoch 3/10 Iteration: 5000 Avg. Training loss: 4.3044 0.3212 sec/batch
# Nearest to will: fail, sentinels, cryptozoologists, lxx, antlia, stash, popperian, apsaras,
# Nearest to and: contaminants, hotly, crystals, stardust, yf, taz, purported, valuing,
# Nearest to which: doctors, oxus, homologous, decss, ibizan, rapping, bigg, darkly,
# Nearest to state: kristianstad, petitioning, retreated, udp, plausibly, bastille, reclaiming, hobson,
# Nearest to over: unb, juvenile, auxerre, lownds, downland, simpler, merengue, drafts,
# Nearest to on: lautrec, marketers, imitates, pathfinder, kapit, trifling, mistaken, viking,
# Nearest to this: injera, motorized, airspeeds, zigzag, prevalent, concludes, providencia, tapering,
# Nearest to four: worst, vanier, powerplants, grimmett, commodities, answered, interleaved, piet,
# Nearest to bible: cmd, pictorial, bunk, suggesting, uniquely, ideographic, facilitation, holies,
# Nearest to articles: endowment, analytic, beheld, sufficed, phaenomena, doren, gleam, pell,
# Nearest to hold: stallman, carvey, solidifies, muratorian, lightened, pelias, confidence, contre,
# Nearest to brother: illustrator, croce, defiled, magistracy, sammy, ariane, baines, lea,
# Nearest to creation: distasteful, golda, secessionist, render, donoghue, hosts, phagocytic, nepal,
# Nearest to bbc: abbr, coolidge, dealerships, riccati, almanack, vest, gion, zuid,
# Nearest to governor: kees, eicher, pedro, ratisbon, woodward, chronicling, beauty, shocks,
# Nearest to numerous: tracts, cities, matthias, barons, grasps, hierarchy, abd, convict,
# Epoch 3/10 Iteration: 5100 Avg. Training loss: 4.3000 0.3151 sec/batch
# Epoch 3/10 Iteration: 5200 Avg. Training loss: 4.3045 0.2949 sec/batch
# Epoch 3/10 Iteration: 5300 Avg. Training loss: 4.2990 0.3005 sec/batch
# Epoch 3/10 Iteration: 5400 Avg. Training loss: 4.2629 0.3028 sec/batch
# Epoch 3/10 Iteration: 5500 Avg. Training loss: 4.3352 0.3101 sec/batch
# Epoch 3/10 Iteration: 5600 Avg. Training loss: 4.2548 0.3044 sec/batch
# Epoch 3/10 Iteration: 5700 Avg. Training loss: 4.2395 0.3009 sec/batch
# Epoch 3/10 Iteration: 5800 Avg. Training loss: 4.2845 0.3015 sec/batch
# Epoch 4/10 Iteration: 5900 Avg. Training loss: 4.2694 0.1233 sec/batch
# Epoch 4/10 Iteration: 6000 Avg. Training loss: 4.1533 0.3086 sec/batch
# Nearest to will: fail, sentinels, cryptozoologists, antlia, lxx, stash, apsaras, ohm,
# Nearest to and: contaminants, hotly, stardust, valuing, affable, ayawaska, taz, purported,
# Nearest to which: oxus, doctors, homologous, ibizan, freethought, decss, rapping, darkly,
# Nearest to state: petitioning, kristianstad, retreated, udp, plausibly, transparency, hobson, bastille,
# Nearest to over: unb, juvenile, auxerre, downland, lownds, algal, boland, simpler,
# Nearest to on: lautrec, kapit, trifling, imitates, squarely, procuring, marketers, improvised,
# Nearest to this: injera, providencia, motorized, zigzag, concludes, airspeeds, tapering, prevalent,
# Nearest to four: worst, vanier, grimmett, interleaved, powerplants, isbn, piet, pirate,
# Nearest to bible: cmd, pictorial, bunk, suggesting, uniquely, ideographic, holies, facilitation,
# Nearest to articles: endowment, analytic, beheld, phaenomena, doren, sufficed, gleam, eldorado,
# Nearest to hold: stallman, carvey, lightened, pelias, muratorian, solidifies, confidence, contre,
# Nearest to brother: illustrator, defiled, croce, magistracy, sammy, loos, belarusians, manon,
# Nearest to creation: distasteful, secessionist, golda, render, phagocytic, nepal, hosts, increase,
# Nearest to bbc: abbr, coolidge, riccati, dealerships, amato, japanese, vest, ewen,
# Nearest to governor: kees, pedro, eicher, woodward, coup, beringei, ratisbon, mutinous,
# Nearest to numerous: tracts, cities, convict, matthias, specialization, grasps, barons, hierarchy,
# Epoch 4/10 Iteration: 6100 Avg. Training loss: 4.1271 0.3102 sec/batch
# Epoch 4/10 Iteration: 6200 Avg. Training loss: 4.1860 0.3157 sec/batch
# Epoch 4/10 Iteration: 6300 Avg. Training loss: 4.1912 0.3290 sec/batch
# Epoch 4/10 Iteration: 6400 Avg. Training loss: 4.1749 0.3306 sec/batch
# Epoch 4/10 Iteration: 6500 Avg. Training loss: 4.1131 0.3109 sec/batch
# Epoch 4/10 Iteration: 6600 Avg. Training loss: 4.1658 0.3044 sec/batch
# Epoch 4/10 Iteration: 6700 Avg. Training loss: 4.1756 0.3218 sec/batch
# Epoch 4/10 Iteration: 6800 Avg. Training loss: 4.1498 0.3252 sec/batch
# Epoch 4/10 Iteration: 6900 Avg. Training loss: 4.1222 0.3238 sec/batch
# Epoch 4/10 Iteration: 7000 Avg. Training loss: 4.2009 0.3189 sec/batch
# Nearest to will: fail, sentinels, antlia, cryptozoologists, lxx, popperian, stash, apsaras,
# Nearest to and: valuing, contaminants, ayawaska, hotly, affable, taz, stardust, hebe,
# Nearest to which: oxus, homologous, doctors, decss, ibizan, bigg, freethought, darkly,
# Nearest to state: petitioning, kristianstad, udp, retreated, transparency, hobson, bastille, lethbridge,
# Nearest to over: unb, juvenile, auxerre, downland, lownds, algal, separated, boland,
# Nearest to on: lautrec, imitates, kapit, marketers, improvised, procuring, squarely, trifling,
# Nearest to this: injera, zigzag, providencia, motorized, airspeeds, concludes, vires, tapering,
# Nearest to four: worst, vanier, grimmett, powerplants, piet, pirate, commodities, akhdar,
# Nearest to bible: cmd, uniquely, pictorial, bunk, holies, suggesting, isaiah, witnesses,
# Nearest to articles: endowment, phaenomena, analytic, eldorado, beheld, sufficed, doren, gleam,
# Nearest to hold: stallman, muratorian, lightened, carvey, pelias, solidifies, confidence, contre,
# Nearest to brother: illustrator, croce, defiled, sammy, wimsey, verses, rehearsing, loos,
# Nearest to creation: distasteful, phagocytic, render, secessionist, hosts, increase, nepal, golda,
# Nearest to bbc: abbr, coolidge, dealerships, riccati, amato, ewen, japanese, bierce,
# Nearest to governor: kees, eicher, pedro, coup, woodward, beringei, mutinous, ratisbon,
# Nearest to numerous: tracts, cities, grasps, matthias, specialization, hierarchy, barons, discrediting,
# Epoch 4/10 Iteration: 7100 Avg. Training loss: 4.1557 0.3089 sec/batch
# Epoch 4/10 Iteration: 7200 Avg. Training loss: 4.1446 0.3170 sec/batch
# Epoch 4/10 Iteration: 7300 Avg. Training loss: 4.1405 0.3051 sec/batch
# Epoch 4/10 Iteration: 7400 Avg. Training loss: 4.1837 0.3147 sec/batch
# Epoch 4/10 Iteration: 7500 Avg. Training loss: 4.2310 0.3373 sec/batch
# Epoch 4/10 Iteration: 7600 Avg. Training loss: 4.1011 0.3029 sec/batch
# Epoch 4/10 Iteration: 7700 Avg. Training loss: 4.1612 0.2629 sec/batch
# Epoch 4/10 Iteration: 7800 Avg. Training loss: 4.1306 0.2849 sec/batch
# Epoch 5/10 Iteration: 7900 Avg. Training loss: 4.0944 0.2683 sec/batch
# Epoch 5/10 Iteration: 8000 Avg. Training loss: 4.0254 0.3262 sec/batch
# Nearest to will: fail, sentinels, antlia, stash, cryptozoologists, wffs, mmorpgs, butcher,
# Nearest to and: ayawaska, contaminants, valuing, wraith, hotly, taz, stardust, affable,
# Nearest to which: oxus, homologous, ibizan, doctors, decss, freethought, mounted, darkly,
# Nearest to state: kristianstad, petitioning, udp, hobson, retreated, lethbridge, transparency, bastille,
# Nearest to over: unb, juvenile, auxerre, lownds, separated, downland, algal, boland,
# Nearest to on: lautrec, kapit, procuring, imitates, trifling, squarely, hoffa, caplan,
# Nearest to this: injera, providencia, zigzag, earns, vires, motorized, airspeeds, qt,
# Nearest to four: worst, vanier, grimmett, interleaved, isbn, pirate, arta, taca,
# Nearest to bible: cmd, uniquely, holies, pictorial, suggesting, bunk, isaiah, ideographic,
# Nearest to articles: endowment, beheld, eldorado, gleam, doren, phaenomena, sufficed, analytic,
# Nearest to hold: stallman, muratorian, pelias, lightened, carvey, solidifies, confidence, spiritualism,
# Nearest to brother: croce, illustrator, defiled, verses, stabbed, wimsey, cynic, loos,
# Nearest to creation: distasteful, render, phagocytic, secessionist, confidentiality, increase, halevi, golda,
# Nearest to bbc: abbr, coolidge, riccati, dealerships, amato, japanese, bierce, ewen,
# Nearest to governor: eicher, kees, coup, pedro, woodward, beringei, polska, ratisbon,
# Nearest to numerous: tracts, cities, hierarchy, specialization, grasps, barons, anzus, matthias,
# Epoch 5/10 Iteration: 8100 Avg. Training loss: 4.0462 0.3151 sec/batch
# Epoch 5/10 Iteration: 8200 Avg. Training loss: 4.0604 0.3222 sec/batch
# Epoch 5/10 Iteration: 8300 Avg. Training loss: 4.0556 0.3092 sec/batch
# Epoch 5/10 Iteration: 8400 Avg. Training loss: 4.0142 0.3583 sec/batch
# Epoch 5/10 Iteration: 8500 Avg. Training loss: 4.0087 0.3452 sec/batch
# Epoch 5/10 Iteration: 8600 Avg. Training loss: 4.0403 0.3269 sec/batch
# Epoch 5/10 Iteration: 8700 Avg. Training loss: 4.0788 0.3159 sec/batch
# Epoch 5/10 Iteration: 8800 Avg. Training loss: 4.0552 0.3190 sec/batch
# Epoch 5/10 Iteration: 8900 Avg. Training loss: 4.0071 0.3100 sec/batch
# Epoch 5/10 Iteration: 9000 Avg. Training loss: 4.0652 0.3082 sec/batch
# Nearest to will: sentinels, fail, mmorpgs, antlia, butcher, wffs, tadpoles, apsaras,
# Nearest to and: contaminants, valuing, taz, ayawaska, wraith, hotly, stardust, affable,
# Nearest to which: oxus, homologous, ibizan, doctors, decss, freethought, bigg, mounted,
# Nearest to state: petitioning, kristianstad, udp, hobson, transparency, lethbridge, retreated, bastille,
# Nearest to over: unb, juvenile, auxerre, algal, separated, downland, lownds, boland,
# Nearest to on: lautrec, kapit, procuring, imitates, marketers, improvised, hoffa, trifling,
# Nearest to this: providencia, injera, zigzag, earns, vires, motorized, airspeeds, tapering,
# Nearest to four: worst, grimmett, vanier, isbn, pirate, interleaved, assured, varna,
# Nearest to bible: uniquely, cmd, holies, pictorial, suggesting, isaiah, refutations, bunk,
# Nearest to articles: endowment, eldorado, beheld, phaenomena, doren, gleam, developers, diagnostics,
# Nearest to hold: muratorian, stallman, carvey, pelias, solidifies, lightened, contre, shall,
# Nearest to brother: croce, illustrator, defiled, wimsey, verses, stabbed, cynic, loos,
# Nearest to creation: distasteful, phagocytic, confidentiality, secessionist, entail, render, halevi, mb,
# Nearest to bbc: abbr, coolidge, dealerships, riccati, bierce, ewen, amato, japanese,
# Nearest to governor: kees, coup, eicher, pedro, polska, woodward, beringei, ratisbon,
# Nearest to numerous: tracts, discrediting, hierarchy, grasps, showed, barons, matthias, specialization,
# Epoch 5/10 Iteration: 9100 Avg. Training loss: 4.0492 0.3149 sec/batch
# Epoch 5/10 Iteration: 9200 Avg. Training loss: 4.0809 0.3126 sec/batch
# Epoch 5/10 Iteration: 9300 Avg. Training loss: 4.0398 0.3235 sec/batch
# Epoch 5/10 Iteration: 9400 Avg. Training loss: 4.1319 0.3241 sec/batch
# Epoch 5/10 Iteration: 9500 Avg. Training loss: 4.0767 0.3138 sec/batch
# Epoch 5/10 Iteration: 9600 Avg. Training loss: 3.9995 0.3087 sec/batch
# Epoch 5/10 Iteration: 9700 Avg. Training loss: 4.0389 0.3536 sec/batch
# Epoch 6/10 Iteration: 9800 Avg. Training loss: 4.0737 0.1388 sec/batch
# Epoch 6/10 Iteration: 9900 Avg. Training loss: 3.9527 0.3584 sec/batch
# Epoch 6/10 Iteration: 10000 Avg. Training loss: 3.9489 0.3270 sec/batch
# Nearest to will: fail, sentinels, mmorpgs, butcher, antlia, wffs, apsaras, tadpoles,
# Nearest to and: contaminants, ayawaska, taz, wraith, valuing, stardust, hotly, julmust,
# Nearest to which: oxus, ibizan, homologous, bigg, decss, mounted, propped, doctors,
# Nearest to state: petitioning, kristianstad, udp, lethbridge, transparency, hobson, sloan, retreated,
# Nearest to over: unb, juvenile, separated, auxerre, algal, boland, lownds, liao,
# Nearest to on: kapit, lautrec, procuring, improvised, imitates, creutzfeldt, trifling, squarely,
# Nearest to this: injera, providencia, earns, vires, zigzag, qt, tapering, concludes,
# Nearest to four: worst, grimmett, vanier, isbn, arta, interleaved, answered, torgau,
# Nearest to bible: holies, cmd, uniquely, refutations, suggesting, pictorial, isaiah, ideographic,
# Nearest to articles: endowment, eldorado, doren, phaenomena, beheld, gleam, sufficed, trade,
# Nearest to hold: muratorian, stallman, carvey, pelias, lightened, solidifies, confidence, contre,
# Nearest to brother: croce, illustrator, stabbed, defiled, verses, wimsey, lebrun, loos,
# Nearest to creation: confidentiality, secessionist, entail, phagocytic, distasteful, mb, render, sati,
# Nearest to bbc: abbr, coolidge, dealerships, riccati, bierce, japanese, ewen, almanack,
# Nearest to governor: kees, eicher, coup, polska, pedro, woodward, beringei, mutinous,
# Nearest to numerous: tracts, hierarchy, grasps, barons, discrediting, showed, residual, baker,
# Epoch 6/10 Iteration: 10100 Avg. Training loss: 3.9692 0.3279 sec/batch
# Epoch 6/10 Iteration: 10200 Avg. Training loss: 3.9963 0.3088 sec/batch
# Epoch 6/10 Iteration: 10300 Avg. Training loss: 3.9643 0.3162 sec/batch
# Epoch 6/10 Iteration: 10400 Avg. Training loss: 3.9129 0.3082 sec/batch
# Epoch 6/10 Iteration: 10500 Avg. Training loss: 3.9456 0.3089 sec/batch
# Epoch 6/10 Iteration: 10600 Avg. Training loss: 3.9900 0.2936 sec/batch
# Epoch 6/10 Iteration: 10700 Avg. Training loss: 3.9385 0.3129 sec/batch
# Epoch 6/10 Iteration: 10800 Avg. Training loss: 3.9701 0.3128 sec/batch
# Epoch 6/10 Iteration: 10900 Avg. Training loss: 3.9724 0.3125 sec/batch
# Epoch 6/10 Iteration: 11000 Avg. Training loss: 3.9762 0.3084 sec/batch
# Nearest to will: fail, sentinels, butcher, antlia, mmorpgs, wffs, approximating, tadpoles,
# Nearest to and: ayawaska, contaminants, valuing, taz, julmust, hotly, cfr, affable,
# Nearest to which: oxus, ibizan, homologous, decss, bigg, propped, mounted, doctors,
# Nearest to state: petitioning, kristianstad, udp, lethbridge, hobson, transparency, retreated, sloan,
# Nearest to over: unb, juvenile, separated, algal, auxerre, cyclists, boland, lownds,
# Nearest to on: kapit, lautrec, improvised, procuring, creutzfeldt, imitates, marketers, squarely,
# Nearest to this: providencia, injera, vires, earns, zigzag, motorized, tapering, episteme,
# Nearest to four: worst, grimmett, vanier, pirate, torgau, isbn, answered, taca,
# Nearest to bible: holies, uniquely, cmd, refutations, pictorial, isaiah, suggesting, ideographic,
# Nearest to articles: endowment, doren, phaenomena, gleam, eldorado, beheld, developers, canter,
# Nearest to hold: muratorian, carvey, stallman, lightened, solidifies, pelias, confidence, emblems,
# Nearest to brother: croce, stabbed, illustrator, defiled, wimsey, verses, loos, lebrun,
# Nearest to creation: confidentiality, mb, secessionist, phagocytic, biased, halevi, distasteful, entail,
# Nearest to bbc: abbr, dealerships, coolidge, riccati, bierce, almanack, japanese, ewen,
# Nearest to governor: kees, eicher, coup, fencer, polska, beringei, woodward, pedro,
# Nearest to numerous: tracts, grasps, discrediting, barons, baker, showed, residual, bolus,
# Epoch 6/10 Iteration: 11100 Avg. Training loss: 3.9988 0.2963 sec/batch
# Epoch 6/10 Iteration: 11200 Avg. Training loss: 3.9967 0.3106 sec/batch
# Epoch 6/10 Iteration: 11300 Avg. Training loss: 3.9929 0.3122 sec/batch
# Epoch 6/10 Iteration: 11400 Avg. Training loss: 3.9931 0.3090 sec/batch
# Epoch 6/10 Iteration: 11500 Avg. Training loss: 3.9682 0.3135 sec/batch
# Epoch 6/10 Iteration: 11600 Avg. Training loss: 3.9698 0.3170 sec/batch
# Epoch 6/10 Iteration: 11700 Avg. Training loss: 3.9739 0.3158 sec/batch
# Epoch 7/10 Iteration: 11800 Avg. Training loss: 3.9787 0.2709 sec/batch
# Epoch 7/10 Iteration: 11900 Avg. Training loss: 3.8539 0.3201 sec/batch
# Epoch 7/10 Iteration: 12000 Avg. Training loss: 3.8727 0.3252 sec/batch
# Nearest to will: fail, sentinels, butcher, antlia, mmorpgs, wffs, troop, tadpoles,
# Nearest to and: ayawaska, contaminants, julmust, hotly, wraith, valuing, cfr, purported,
# Nearest to which: ibizan, oxus, homologous, bigg, decss, propped, mounted, levees,
# Nearest to state: petitioning, kristianstad, lethbridge, udp, hobson, sloan, transparency, retreated,
# Nearest to over: unb, juvenile, separated, auxerre, algal, boland, cyclists, lownds,
# Nearest to on: kapit, procuring, lautrec, improvised, imitates, creutzfeldt, caplan, hoffa,
# Nearest to this: providencia, vires, injera, earns, tapering, zigzag, qt, motorized,
# Nearest to four: worst, grimmett, vanier, answered, torgau, pirate, taca, mnir,
# Nearest to bible: holies, cmd, uniquely, refutations, ideographic, suggesting, pictorial, isaiah,
# Nearest to articles: endowment, eldorado, doren, developers, phaenomena, gleam, sufficed, beheld,
# Nearest to hold: muratorian, carvey, stallman, disengagement, contre, confidence, shall, emblems,
# Nearest to brother: stabbed, croce, illustrator, wimsey, loos, defiled, verses, lasor,
# Nearest to creation: mb, confidentiality, secessionist, biased, halevi, render, entail, golda,
# Nearest to bbc: abbr, dealerships, coolidge, bierce, almanack, japanese, ewen, riccati,
# Nearest to governor: kees, eicher, coup, fencer, polska, pedro, woodward, beringei,
# Nearest to numerous: tracts, residual, baker, isotopic, grasps, discrediting, showed, barons,
# Epoch 7/10 Iteration: 12100 Avg. Training loss: 3.9215 0.3297 sec/batch
# Epoch 7/10 Iteration: 12200 Avg. Training loss: 3.8955 0.3100 sec/batch
# Epoch 7/10 Iteration: 12300 Avg. Training loss: 3.8640 0.2893 sec/batch
# Epoch 7/10 Iteration: 12400 Avg. Training loss: 3.8538 0.3172 sec/batch
# Epoch 7/10 Iteration: 12500 Avg. Training loss: 3.9139 0.3303 sec/batch
# Epoch 7/10 Iteration: 12600 Avg. Training loss: 3.9077 0.3070 sec/batch
# Epoch 7/10 Iteration: 12700 Avg. Training loss: 3.9035 0.3187 sec/batch
# Epoch 7/10 Iteration: 12800 Avg. Training loss: 3.9170 0.3072 sec/batch
# Epoch 7/10 Iteration: 12900 Avg. Training loss: 3.9481 0.3120 sec/batch
# Epoch 7/10 Iteration: 13000 Avg. Training loss: 3.9382 0.3075 sec/batch
# Nearest to will: fail, butcher, sentinels, troop, mmorpgs, antlia, wffs, thrusting,
# Nearest to and: ayawaska, hotly, valuing, julmust, contaminants, imaginations, cfr, rado,
# Nearest to which: ibizan, oxus, homologous, bigg, decss, levees, ditched, propped,
# Nearest to state: petitioning, kristianstad, lethbridge, udp, hobson, sloan, transparency, retreated,
# Nearest to over: unb, separated, juvenile, lownds, algal, auxerre, cyclists, boland,
# Nearest to on: kapit, procuring, lautrec, improvised, imitates, caplan, hoffa, tee,
# Nearest to this: vires, earns, providencia, injera, tapering, zigzag, motorized, choice,
# Nearest to four: worst, grimmett, answered, vanier, torgau, assured, isbn, taca,
# Nearest to bible: holies, cmd, uniquely, refutations, ideographic, itzhak, pictorial, suggesting,
# Nearest to articles: endowment, eldorado, doren, beheld, phaenomena, frivolous, developers, gleam,
# Nearest to hold: muratorian, carvey, stallman, solidifies, csc, synoptics, emblems, lightened,
# Nearest to brother: stabbed, croce, illustrator, wimsey, loos, lebrun, exceedingly, lasor,
# Nearest to creation: mb, confidentiality, secessionist, biased, halevi, hosts, sati, entail,
# Nearest to bbc: dealerships, abbr, coolidge, almanack, bierce, japanese, ewen, riccati,
# Nearest to governor: kees, eicher, coup, fencer, beringei, amend, shocks, polska,
# Nearest to numerous: tracts, grasps, baker, residual, barons, upstairs, scifan, isotopic,
# Epoch 7/10 Iteration: 13100 Avg. Training loss: 3.9205 0.3108 sec/batch
# Epoch 7/10 Iteration: 13200 Avg. Training loss: 3.9233 0.3061 sec/batch
# Epoch 7/10 Iteration: 13300 Avg. Training loss: 3.9668 0.3071 sec/batch
# Epoch 7/10 Iteration: 13400 Avg. Training loss: 3.9388 0.3253 sec/batch
# Epoch 7/10 Iteration: 13500 Avg. Training loss: 3.8715 0.3212 sec/batch
# Epoch 7/10 Iteration: 13600 Avg. Training loss: 3.9420 0.3285 sec/batch
# Epoch 8/10 Iteration: 13700 Avg. Training loss: 3.9275 0.0918 sec/batch
# Epoch 8/10 Iteration: 13800 Avg. Training loss: 3.8431 0.3170 sec/batch
# Epoch 8/10 Iteration: 13900 Avg. Training loss: 3.8075 0.3336 sec/batch
# Epoch 8/10 Iteration: 14000 Avg. Training loss: 3.8957 0.3226 sec/batch
# Nearest to will: fail, butcher, sentinels, troop, antlia, mmorpgs, ohm, wffs,
# Nearest to and: julmust, ayawaska, valuing, hotly, kcr, contaminants, stardust, colophon,
# Nearest to which: ibizan, homologous, bigg, oxus, levees, decss, propped, mounted,
# Nearest to state: petitioning, kristianstad, lethbridge, udp, hobson, retreated, teamsters, sloan,
# Nearest to over: unb, separated, juvenile, algal, lownds, auxerre, policymakers, cyclists,
# Nearest to on: kapit, procuring, lautrec, caplan, improvised, imitates, creutzfeldt, pavlov,
# Nearest to this: earns, vires, providencia, injera, tapering, motorized, zigzag, qt,
# Nearest to four: worst, grimmett, answered, vanier, assured, torgau, isbn, kee,
# Nearest to bible: holies, cmd, uniquely, refutations, ideographic, itzhak, noblesse, pictorial,
# Nearest to articles: endowment, doren, eldorado, phaenomena, redfern, blogging, developers, beheld,
# Nearest to hold: muratorian, carvey, stallman, synoptics, disengagement, shall, emblems, csc,
# Nearest to brother: stabbed, croce, illustrator, loos, wimsey, lasor, guimar, exceedingly,
# Nearest to creation: confidentiality, mb, halevi, biased, secessionist, phagocytic, render, entail,
# Nearest to bbc: dealerships, abbr, coolidge, almanack, japanese, ewen, riccati, bierce,
# Nearest to governor: kees, eicher, fencer, coup, woodward, floodplain, beringei, polska,
# Nearest to numerous: tracts, residual, grasps, upstairs, baker, hierarchy, cities, isotopic,
# Epoch 8/10 Iteration: 14100 Avg. Training loss: 3.8252 0.3313 sec/batch
# Epoch 8/10 Iteration: 14200 Avg. Training loss: 3.8435 0.3204 sec/batch
# Epoch 8/10 Iteration: 14300 Avg. Training loss: 3.7559 0.3199 sec/batch
# Epoch 8/10 Iteration: 14400 Avg. Training loss: 3.8731 0.3198 sec/batch
# Epoch 8/10 Iteration: 14500 Avg. Training loss: 3.8706 0.3201 sec/batch
# Epoch 8/10 Iteration: 14600 Avg. Training loss: 3.8313 0.3208 sec/batch
# Epoch 8/10 Iteration: 14700 Avg. Training loss: 3.8724 0.3203 sec/batch
# Epoch 8/10 Iteration: 14800 Avg. Training loss: 3.9041 0.3206 sec/batch
# Epoch 8/10 Iteration: 14900 Avg. Training loss: 3.8656 0.3209 sec/batch
# Epoch 8/10 Iteration: 15000 Avg. Training loss: 3.9138 0.3202 sec/batch
# Nearest to will: butcher, fail, sentinels, troop, antlia, unawares, wffs, approximating,
# Nearest to and: valuing, colophon, julmust, rado, ayawaska, yf, taz, scandinavia,
# Nearest to which: oxus, ibizan, homologous, bigg, levees, issue, propped, decss,
# Nearest to state: petitioning, kristianstad, lethbridge, udp, hobson, conurbation, retreated, teamsters,
# Nearest to over: unb, separated, juvenile, algal, policymakers, lownds, auxerre, boland,
# Nearest to on: kapit, procuring, improvised, lautrec, caplan, pavlov, imitates, creutzfeldt,
# Nearest to this: vires, providencia, earns, injera, tapering, hesitate, qt, zigzag,
# Nearest to four: worst, grimmett, answered, torgau, assured, vanier, mnir, pirate,
# Nearest to bible: holies, cmd, uniquely, refutations, ideographic, itzhak, noblesse, suggesting,
# Nearest to articles: endowment, doren, blogging, eldorado, phaenomena, developers, redfern, beheld,
# Nearest to hold: muratorian, csc, disengagement, carvey, emblems, reformist, synoptics, shall,
# Nearest to brother: croce, stabbed, exceedingly, illustrator, wimsey, loos, guimar, lasor,
# Nearest to creation: mb, confidentiality, halevi, secessionist, biased, phagocytic, sati, entail,
# Nearest to bbc: dealerships, abbr, ewen, coolidge, almanack, bierce, riccati, japanese,
# Nearest to governor: kees, eicher, fencer, coup, floodplain, amend, beringei, woodward,
# Nearest to numerous: tracts, grasps, baker, residual, upstairs, barons, scifan, hacked,
# Epoch 8/10 Iteration: 15100 Avg. Training loss: 3.8587 0.3252 sec/batch
# Epoch 8/10 Iteration: 15200 Avg. Training loss: 3.9079 0.3233 sec/batch
# Epoch 8/10 Iteration: 15300 Avg. Training loss: 3.9217 0.3208 sec/batch
# Epoch 8/10 Iteration: 15400 Avg. Training loss: 3.8197 0.3199 sec/batch
# Epoch 8/10 Iteration: 15500 Avg. Training loss: 3.9346 0.3204 sec/batch
# Epoch 8/10 Iteration: 15600 Avg. Training loss: 3.8907 0.3208 sec/batch
# Epoch 9/10 Iteration: 15700 Avg. Training loss: 3.8624 0.2453 sec/batch
# Epoch 9/10 Iteration: 15800 Avg. Training loss: 3.7790 0.3216 sec/batch
# Epoch 9/10 Iteration: 15900 Avg. Training loss: 3.7513 0.3214 sec/batch
# Epoch 9/10 Iteration: 16000 Avg. Training loss: 3.7939 0.3198 sec/batch
# Nearest to will: butcher, fail, troop, sentinels, antlia, unawares, approximating, wffs,
# Nearest to and: valuing, julmust, amelia, yf, hotly, ayawaska, colophon, rado,
# Nearest to which: ibizan, bigg, oxus, homologous, levees, issue, decss, darkly,
# Nearest to state: petitioning, lethbridge, kristianstad, udp, hobson, sloan, conurbation, underrepresented,
# Nearest to over: unb, separated, juvenile, policymakers, algal, dhimma, auxerre, boland,
# Nearest to on: kapit, improvised, procuring, caplan, lautrec, pavlov, imitates, creutzfeldt,
# Nearest to this: providencia, vires, earns, injera, tapering, hesitate, gallon, richard,
# Nearest to four: worst, grimmett, answered, taca, mt, assured, kee, vanier,
# Nearest to bible: holies, cmd, uniquely, ideographic, itzhak, noblesse, refutations, suggesting,
# Nearest to articles: endowment, doren, blogging, eldorado, sufficed, beheld, developers, redfern,
# Nearest to hold: csc, muratorian, disengagement, reformist, synoptics, lightened, emblems, carvey,
# Nearest to brother: stabbed, croce, illustrator, guimar, exceedingly, mus, wimsey, loos,
# Nearest to creation: confidentiality, mb, secessionist, halevi, biased, sati, phagocytic, mekhilta,
# Nearest to bbc: dealerships, abbr, expandability, ewen, coolidge, japanese, bierce, almanack,
# Nearest to governor: eicher, kees, fencer, coup, shocks, amend, floodplain, woodward,
# Nearest to numerous: tracts, baker, residual, grasps, upstairs, hacked, hierarchy, scifan,
# Epoch 9/10 Iteration: 16100 Avg. Training loss: 3.8223 0.3413 sec/batch
# Epoch 9/10 Iteration: 16200 Avg. Training loss: 3.7873 0.3241 sec/batch
# Epoch 9/10 Iteration: 16300 Avg. Training loss: 3.8078 0.3196 sec/batch
# Epoch 9/10 Iteration: 16400 Avg. Training loss: 3.7814 0.3204 sec/batch
# Epoch 9/10 Iteration: 16500 Avg. Training loss: 3.8305 0.3213 sec/batch
# Epoch 9/10 Iteration: 16600 Avg. Training loss: 3.8192 0.3252 sec/batch
# Epoch 9/10 Iteration: 16700 Avg. Training loss: 3.8202 0.3117 sec/batch
# Epoch 9/10 Iteration: 16800 Avg. Training loss: 3.8712 0.3209 sec/batch
# Epoch 9/10 Iteration: 16900 Avg. Training loss: 3.8770 0.3213 sec/batch
# Epoch 9/10 Iteration: 17000 Avg. Training loss: 3.8519 0.3186 sec/batch
# Nearest to will: butcher, fail, antlia, sentinels, approximating, unawares, troop, tadpoles,
# Nearest to and: colophon, valuing, amelia, hotly, rado, yf, taz, scandinavia,
# Nearest to which: oxus, bigg, ibizan, levees, homologous, issue, freethought, law,
# Nearest to state: lethbridge, petitioning, kristianstad, udp, hobson, sloan, underrepresented, rda,
# Nearest to over: unb, separated, juvenile, algal, policymakers, lownds, boland, auxerre,
# Nearest to on: kapit, procuring, caplan, improvised, lautrec, pavlov, creutzfeldt, imitates,
# Nearest to this: vires, providencia, earns, injera, tapering, hesitate, richard, gallon,
# Nearest to four: worst, grimmett, assured, answered, torgau, pirate, taca, mt,
# Nearest to bible: cmd, holies, uniquely, ideographic, itzhak, noblesse, suggesting, refutations,
# Nearest to articles: endowment, doren, blogging, eldorado, phaenomena, sufficed, beheld, redfern,
# Nearest to hold: csc, muratorian, emblems, reformist, synoptics, lightened, carvey, spiritualism,
# Nearest to brother: croce, stabbed, exceedingly, illustrator, guimar, loos, mus, wimsey,
# Nearest to creation: mb, confidentiality, secessionist, biased, halevi, sati, mekhilta, phagocytic,
# Nearest to bbc: dealerships, ewen, coolidge, izzard, abbr, expandability, bierce, riccati,
# Nearest to governor: eicher, kees, fencer, shocks, beringei, amend, coup, floodplain,
# Nearest to numerous: tracts, baker, residual, grasps, hacked, upstairs, scifan, airing,
# Epoch 9/10 Iteration: 17100 Avg. Training loss: 3.8668 0.3292 sec/batch
# Epoch 9/10 Iteration: 17200 Avg. Training loss: 3.9336 0.3363 sec/batch
# Epoch 9/10 Iteration: 17300 Avg. Training loss: 3.8402 0.3215 sec/batch
# Epoch 9/10 Iteration: 17400 Avg. Training loss: 3.7960 0.3289 sec/batch
# Epoch 9/10 Iteration: 17500 Avg. Training loss: 3.8396 0.3290 sec/batch
# Epoch 10/10 Iteration: 17600 Avg. Training loss: 3.8259 0.0740 sec/batch
# Epoch 10/10 Iteration: 17700 Avg. Training loss: 3.7623 0.3180 sec/batch
# Epoch 10/10 Iteration: 17800 Avg. Training loss: 3.7383 0.3147 sec/batch
# Epoch 10/10 Iteration: 17900 Avg. Training loss: 3.7600 0.3154 sec/batch
# Epoch 10/10 Iteration: 18000 Avg. Training loss: 3.7609 0.3151 sec/batch
# Nearest to will: butcher, fail, antlia, sentinels, approximating, unawares, troop, tadpoles,
# Nearest to and: colophon, yf, valuing, amelia, hotly, julmust, crystals, ayawaska,
# Nearest to which: levees, ibizan, bigg, oxus, issue, homologous, ditched, forgets,
# Nearest to state: lethbridge, kristianstad, petitioning, hobson, udp, sloan, rda, underrepresented,
# Nearest to over: unb, separated, juvenile, algal, auxerre, lownds, policymakers, indies,
# Nearest to on: kapit, caplan, procuring, improvised, lautrec, creutzfeldt, pavlov, rsa,
# Nearest to this: providencia, vires, injera, earns, hesitate, tapering, gallon, qt,
# Nearest to four: worst, grimmett, assured, taca, torgau, vanier, kee, financi,
# Nearest to bible: cmd, holies, uniquely, noblesse, ideographic, suggesting, itzhak, masoretes,
# Nearest to articles: endowment, doren, blogging, eldorado, sufficed, phaenomena, beheld, redfern,
# Nearest to hold: csc, emblems, carvey, synoptics, muratorian, reformist, dyed, spiritualism,
# Nearest to brother: croce, guimar, stabbed, exceedingly, loos, mus, illustrator, wimsey,
# Nearest to creation: mb, confidentiality, secessionist, biased, halevi, sati, mekhilta, phagocytic,
# Nearest to bbc: dealerships, ewen, coolidge, expandability, amato, abbr, japanese, izzard,
# Nearest to governor: kees, eicher, fencer, beringei, floodplain, servants, shocks, amend,
# Nearest to numerous: tracts, baker, residual, grasps, hacked, scifan, upstairs, abrams,
# Epoch 10/10 Iteration: 18100 Avg. Training loss: 3.7661 0.3208 sec/batch
# Epoch 10/10 Iteration: 18200 Avg. Training loss: 3.7013 0.3142 sec/batch
# Epoch 10/10 Iteration: 18300 Avg. Training loss: 3.7905 0.3166 sec/batch
# Epoch 10/10 Iteration: 18400 Avg. Training loss: 3.7815 0.3157 sec/batch
# Epoch 10/10 Iteration: 18500 Avg. Training loss: 3.8040 0.3179 sec/batch
# Epoch 10/10 Iteration: 18600 Avg. Training loss: 3.8072 0.3202 sec/batch
# Epoch 10/10 Iteration: 18700 Avg. Training loss: 3.8022 0.3262 sec/batch
# Epoch 10/10 Iteration: 18800 Avg. Training loss: 3.7822 0.3165 sec/batch
# Epoch 10/10 Iteration: 18900 Avg. Training loss: 3.7783 0.3177 sec/batch
# Epoch 10/10 Iteration: 19000 Avg. Training loss: 3.7865 0.3174 sec/batch
# Nearest to will: fail, butcher, unawares, antlia, approximating, risch, tadpoles, wffs,
# Nearest to and: colophon, valuing, hotly, intelligibility, rado, amelia, taz, tangier,
# Nearest to which: levees, ibizan, issue, bigg, oxus, mounted, ditched, propped,
# Nearest to state: petitioning, lethbridge, kristianstad, hobson, udp, underrepresented, sloan, conurbation,
# Nearest to over: unb, separated, juvenile, algal, auxerre, policymakers, lownds, boland,
# Nearest to on: kapit, improvised, caplan, procuring, creutzfeldt, rsa, lautrec, pavlov,
# Nearest to this: providencia, vires, earns, injera, hesitate, tapering, richard, gallon,
# Nearest to four: worst, grimmett, assured, torgau, taca, pirate, ogdoad, mt,
# Nearest to bible: cmd, holies, noblesse, uniquely, ideographic, itzhak, masoretes, suggesting,
# Nearest to articles: blogging, endowment, doren, eldorado, phaenomena, sufficed, beheld, redfern,
# Nearest to hold: csc, emblems, muratorian, synoptics, reformist, thread, breech, spiritualism,
# Nearest to brother: croce, exceedingly, stabbed, guimar, illustrator, loos, mus, freethinker,
# Nearest to creation: mb, confidentiality, secessionist, biased, halevi, federico, nepal, mekhilta,
# Nearest to bbc: dealerships, ewen, amato, izzard, baruch, coolidge, japanese, expandability,
# Nearest to governor: eicher, kees, fencer, floodplain, beringei, servants, amend, mutinous,
# Nearest to numerous: tracts, residual, baker, grasps, hacked, upstairs, scifan, abrams,
# Epoch 10/10 Iteration: 19100 Avg. Training loss: 3.8539 0.3215 sec/batch
# Epoch 10/10 Iteration: 19200 Avg. Training loss: 3.8773 0.3172 sec/batch
# Epoch 10/10 Iteration: 19300 Avg. Training loss: 3.7620 0.3154 sec/batch
# Epoch 10/10 Iteration: 19400 Avg. Training loss: 3.7776 0.3167 sec/batch
# Epoch 10/10 Iteration: 19500 Avg. Training loss: 3.8009 0.3164 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
