# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    word_count = Counter(reviews[i].split(" "))
    if labels[i] == 'POSITIVE':
        positive_counts += word_count
    else:
        negative_counts += word_count
    total_counts += word_count

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 693820),
#  ('the', 219482),
#  ('.', 200969),
#  ('and', 112913),
#  ('a', 105392),
#  ('of', 97170),
#  ('to', 84136),
#  ('is', 71834),
#  ('in', 63085),
#  ('br', 62152),
#  ('it', 60404),
#  ('i', 51023),
#  ('that', 44845),
#  ('this', 44017),
#  ('s', 42475),
#  ('as', 33173),
#  ('with', 29108),
#  ('for', 28132),
#  ('was', 27626),
#  ('film', 26247),
#  ('but', 26128),
#  ('movie', 24010),
#  ('his', 21447),
#  ('on', 21391),
#  ('you', 20854),
#  ('he', 20281),
#  ('are', 18667),
#  ('not', 17913),
#  ('one', 17257),
#  ('t', 17209),
#  ('have', 15916),
#  ('be', 15647),
#  ('by', 15084),
#  ('all', 15025),
#  ('who', 14423),
#  ('an', 14224),
#  ('at', 14059),
#  ('from', 13553),
#  ('her', 13352),
#  ('they', 12618),
#  ('has', 11577),
#  ('so', 11386),
#  ('like', 11380),
#  ('about', 10475),
#  ('very', 10455),
#  ('out', 10308),
#  ('there', 10107),
#  ('she', 9907),
#  ('good', 9711),
#  ('or', 9700),
#  ('what', 9690),
#  ('more', 9456),
#  ('some', 9384),
#  ('when', 9331),
#  ('if', 9120),
#  ('just', 9063),
#  ('can', 8787),
#  ('story', 8560),
#  ('time', 8213),
#  ('my', 8123),
#  ('great', 8123),
#  ('well', 8100),
#  ('up', 8007),
#  ('which', 7949),
#  ('their', 7720),
#  ('see', 7552),
#  ('we', 6967),
#  ('also', 6941),
#  ('really', 6786),
#  ('would', 6739),
#  ('had', 6504),
#  ('will', 6491),
#  ('me', 6471),
#  ('only', 6471),
#  ('him', 6279),
#  ('even', 6254),
#  ('other', 6173),
#  ('most', 6161),
#  ('were', 6048),
#  ('first', 6019),
#  ('than', 5929),
#  ('much', 5881),
#  ('into', 5779),
#  ('its', 5777),
#  ('no', 5714),
#  ('people', 5628),
#  ('best', 5426),
#  ('get', 5408),
#  ('love', 5343),
#  ('been', 5328),
#  ('how', 5269),
#  ('because', 5170),
#  ('life', 5164),
#  ('way', 5024),
#  ('do', 4927),
#  ('made', 4838),
#  ('after', 4798),
#  ('films', 4798),
#  ('them', 4755),
#  ('two', 4737),
#  ('many', 4693),
#  ('too', 4617),
#  ('think', 4599),
#  ('characters', 4529),
#  ('movies', 4488),
#  ('character', 4431),
#  ('show', 4418),
#  ('don', 4384),
#  ('watch', 4359),
#  ('seen', 4334),
#  ('man', 4271),
#  ('still', 4264),
#  ('little', 4241),
#  ('then', 4232),
#  ('never', 4130),
#  ('make', 4121),
#  ('could', 4053),
#  ('being', 4004),
#  ('where', 3965),
#  ('over', 3829),
#  ('does', 3787),
#  ('any', 3733),
#  ('while', 3640),
#  ('know', 3558),
#  ('years', 3518),
#  ('ever', 3498),
#  ('did', 3475),
#  ('here', 3431),
#  ('these', 3398),
#  ('end', 3346),
#  ('scene', 3260),
#  ('such', 3254),
#  ('real', 3223),
#  ('back', 3184),
#  ('though', 3138),
#  ('off', 3130),
#  ('new', 3114),
#  ('go', 3085),
#  ('those', 3084),
#  ('acting', 3068),
#  ('plot', 3054),
#  ('say', 3049),
#  ('world', 3044),
#  ('better', 3036),
#  ('your', 3034),
#  ('scenes', 3033),
#  ('makes', 3003),
#  ('through', 2993),
#  ('work', 2935),
#  ('ve', 2926),
#  ('now', 2923),
#  ('old', 2889),
#  ('find', 2863),
#  ('young', 2854),
#  ('both', 2835),
#  ('series', 2791),
#  ('before', 2787),
#  ('again', 2745),
#  ('quite', 2704),
#  ('cast', 2698),
#  ('lot', 2689),
#  ('should', 2678),
#  ('something', 2656),
#  ('us', 2656),
#  ('always', 2634),
#  ('part', 2603),
#  ('another', 2592),
#  ('actors', 2562),
#  ('director', 2539),
#  ('m', 2521),
#  ('family', 2521),
#  ('own', 2517),
#  ('may', 2500),
#  ('same', 2468),
#  ('every', 2468),
#  ('bad', 2464),
#  ('few', 2463),
#  ('between', 2461),
#  ('watching', 2437),
#  ('doesn', 2429),
#  ('role', 2427),
#  ('funny', 2415),
#  ('look', 2407),
#  ('performance', 2387),
#  ('re', 2330),
#  ('things', 2325),
#  ('times', 2322),
#  ('big', 2304),
#  ('why', 2289),
#  ('actually', 2277),
#  ('however', 2275),
#  ('action', 2255),
#  ('going', 2237),
#  ('down', 2234),
#  ('bit', 2217),
#  ('comedy', 2211),
#  ('must', 2210),
#  ('music', 2163),
#  ('long', 2160),
#  ('right', 2148),
#  ('take', 2145),
#  ('excellent', 2145),
#  ('fact', 2143),
#  ('saw', 2139),
#  ('fun', 2126),
#  ('didn', 2117),
#  ('around', 2112),
#  ('without', 2101),
#  ('got', 2092),
#  ('thing', 2089),
#  ('thought', 2051),
#  ('each', 2044),
#  ('day', 2030),
#  ('seems', 2026),
#  ('feel', 2017),
#  ('done', 2015),
#  ('come', 2005),
#  ('beautiful', 1996),
#  ('give', 1995),
#  ('especially', 1993),
#  ('last', 1984),
#  ('pretty', 1976),
#  ('almost', 1967),
#  ('horror', 1961),
#  ('want', 1959),
#  ('played', 1939),
#  ('true', 1933),
#  ('since', 1921),
#  ('although', 1906),
#  ('gets', 1905),
#  ('yet', 1900),
#  ('interesting', 1893),
#  ('different', 1876),
#  ('job', 1843),
#  ('woman', 1838),
#  ('tv', 1819),
#  ('enough', 1810),
#  ('our', 1796),
#  ('shows', 1791),
#  ('point', 1753),
#  ('course', 1748),
#  ('probably', 1734),
#  ('original', 1733),
#  ('wonderful', 1723),
#  ('plays', 1721),
#  ('girl', 1702),
#  ('far', 1692),
#  ('d', 1683),
#  ('later', 1670),
#  ('dvd', 1667),
#  ('away', 1667),
#  ('nothing', 1666),
#  ('rather', 1665),
#  ('isn', 1659),
#  ('once', 1657),
#  ('ll', 1657),
#  ('john', 1648),
#  ('screen', 1647),
#  ('whole', 1644),
#  ('hard', 1642),
#  ('set', 1636),
#  ('together', 1633),
#  ('found', 1621),
#  ('having', 1616),
#  ('father', 1613),
#  ('year', 1604),
#  ('place', 1597),
#  ('comes', 1593),
#  ('might', 1589),
#  ('perfect', 1588),
#  ('am', 1587),
#  ('american', 1586),
#  ('sure', 1585),
#  ('making', 1575),
#  ('performances', 1558),
#  ('kind', 1553),
#  ('takes', 1551),
#  ('war', 1547),
#  ('house', 1545),
#  ('anyone', 1539),
#  ('everyone', 1539),
#  ('himself', 1538),
#  ('wife', 1529),
#  ('worth', 1528),
#  ('play', 1518),
#  ('ending', 1508),
#  ('three', 1497),
#  ('classic', 1492),
#  ('book', 1482),
#  ('actor', 1475),
#  ('version', 1470),
#  ('goes', 1464),
#  ('star', 1453),
#  ('everything', 1443),
#  ('enjoy', 1426),
#  ('night', 1403),
#  ('guy', 1396),
#  ('least', 1392),
#  ('nice', 1390),
#  ('during', 1390),
#  ('put', 1389),
#  ('seeing', 1385),
#  ('watched', 1373),
#  ('top', 1366),
#  ('episode', 1364),
#  ('loved', 1364),
#  ('anything', 1359),
#  ('believe', 1357),
#  ('men', 1338),
#  ('amazing', 1338),
#  ('high', 1334),
#  ('definitely', 1331),
#  ('hollywood', 1326),
#  ('looking', 1320),
#  ('gives', 1317),
#  ('special', 1309),
#  ('main', 1304),
#  ('second', 1300),
#  ('fan', 1289),
#  ('help', 1286),
#  ('seem', 1286),
#  ('human', 1283),
#  ('truly', 1277),
#  ('audience', 1277),
#  ('short', 1277),
#  ('black', 1267),
#  ('full', 1264),
#  ('sense', 1261),
#  ('along', 1260),
#  ('mind', 1253),
#  ('recommend', 1253),
#  ('home', 1252),
#  ('script', 1239),
#  ('said', 1234),
#  ('small', 1233),
#  ('trying', 1228),
#  ('death', 1227),
#  ('often', 1226),
#  ('heart', 1220),
#  ('until', 1219),
#  ('friends', 1210),
#  ('today', 1210),
#  ('remember', 1207),
#  ('let', 1204),
#  ('left', 1203),
#  ('favorite', 1195),
#  ('live', 1191),
#  ('less', 1174),
#  ('maybe', 1167),
#  ('become', 1167),
#  ('won', 1166),
#  ('early', 1162),
#  ('brilliant', 1161),
#  ('effects', 1161),
#  ('liked', 1157),
#  ('shot', 1155),
#  ('moments', 1152),
#  ('looks', 1150),
#  ('came', 1146),
#  ('used', 1145),
#  ('others', 1143),
#  ('read', 1128),
#  ('perhaps', 1123),
#  ('lives', 1123),
#  ('women', 1119),
#  ('cinema', 1116),
#  ('stars', 1115),
#  ('highly', 1115),
#  ('enjoyed', 1113),
#  ('boy', 1109),
#  ('drama', 1103),
#  ('style', 1101),
#  ('dark', 1097),
#  ('next', 1092),
#  ('line', 1088),
#  ('given', 1084),
#  ('fine', 1081),
#  ('use', 1081),
#  ('picture', 1079),
#  ('playing', 1075),
#  ('entertaining', 1075),
#  ('kids', 1072),
#  ('overall', 1068),
#  ('need', 1065),
#  ('minutes', 1064),
#  ('mother', 1061),
#  ('mr', 1059),
#  ('someone', 1056),
#  ('couple', 1054),
#  ('works', 1049),
#  ('wasn', 1048),
#  ('keep', 1048),
#  ('children', 1045),
#  ('against', 1039),
#  ('simply', 1038),
#  ('certainly', 1037),
#  ('friend', 1029),
#  ('face', 1025),
#  ('based', 1024),
#  ('several', 1022),
#  ('production', 1021),
#  ('michael', 1017),
#  ('history', 1015),
#  ('finally', 1013),
#  ('throughout', 1013),
#  ('else', 1007),
#  ('lost', 1002),
#  ('fans', 1002),
#  ('understand', 1001),
#  ('reason', 997),
#  ('written', 992),
#  ('rest', 989),
#  ('strong', 978),
#  ('school', 968),
#  ('art', 966),
#  ('hope', 964),
#  ('try', 962),
#  ('white', 961),
#  ('genre', 960),
#  ('dead', 960),
#  ('tell', 959),
#  ('son', 951),
#  ('city', 949),
#  ('start', 947),
#  ('money', 946),
#  ('idea', 941),
#  ('beginning', 938),
#  ('sometimes', 936),
#  ('final', 936),
#  ('late', 934),
#  ('past', 933),
#  ('itself', 933),
#  ('case', 929),
#  ('half', 927),
#  ('child', 924),
#  ('becomes', 923),
#  ('person', 922),
#  ('able', 918),
#  ('soon', 918),
#  ('stories', 916),
#  ('camera', 915),
#  ('side', 912),
#  ('yes', 911),
#  ('under', 904),
#  ('despite', 904),
#  ('humor', 903),
#  ('viewer', 900),
#  ('instead', 891),
#  ('getting', 891),
#  ('game', 887),
#  ('completely', 883),
#  ('video', 882),
#  ('jack', 874),
#  ('town', 874),
#  ('felt', 870),
#  ('days', 869),
#  ('roles', 869),
#  ('episodes', 868),
#  ('james', 865),
#  ('wrong', 864),
#  ('turns', 860),
#  ('doing', 859),
#  ('wants', 858),
#  ('either', 858),
#  ('budget', 854),
#  ('close', 851),
#  ('evil', 847),
#  ('simple', 842),
#  ('name', 838),
#  ('called', 833),
#  ('fantastic', 832),
#  ('turn', 831),
#  ('oscar', 830),
#  ('piece', 828),
#  ('relationship', 827),
#  ('went', 823),
#  ('title', 822),
#  ('direction', 819),
#  ('age', 818),
#  ('sort', 815),
#  ('living', 811),
#  ('eyes', 806),
#  ('lead', 801),
#  ('lines', 800),
#  ('head', 800),
#  ('actress', 799),
#  ('absolutely', 799),
#  ('known', 799),
#  ('musical', 798),
#  ('including', 797),
#  ('directed', 797),
#  ('already', 794),
#  ('parts', 794),
#  ('low', 792),
#  ('experience', 789),
#  ('behind', 788),
#  ('sex', 784),
#  ('david', 782),
#  ('example', 781),
#  ('murder', 780),
#  ('season', 777),
#  ('told', 776),
#  ('chance', 774),
#  ('feeling', 772),
#  ('moment', 769),
#  ('themselves', 768),
#  ('score', 765),
#  ('matter', 763),
#  ('supporting', 761),
#  ('ago', 759),
#  ('released', 755),
#  ('moving', 755),
#  ('quality', 752),
#  ('hand', 748),
#  ('documentary', 747),
#  ('husband', 746),
#  ('gave', 745),
#  ('dialogue', 744),
#  ('brother', 744),
#  ('reality', 743),
#  ('hilarious', 743),
#  ('sound', 742),
#  ('coming', 741),
#  ('light', 740),
#  ('finds', 739),
#  ('romantic', 738),
#  ('happy', 737),
#  ('fight', 735),
#  ('particularly', 735),
#  ('hit', 735),
#  ('daughter', 734),
#  ('type', 733),
#  ('enjoyable', 733),
#  ('number', 731),
#  ('expect', 730),
#  ('laugh', 729),
#  ('police', 726),
#  ('voice', 725),
#  ('entire', 724),
#  ('events', 718),
#  ('song', 718),
#  ('future', 717),
#  ('cinematography', 716),
#  ('took', 716),
#  ('paul', 716),
#  ('whose', 715),
#  ('shown', 714),
#  ('killer', 713),
#  ('somewhat', 710),
#  ('king', 708),
#  ('modern', 708),
#  ('superb', 707),
#  ('view', 707),
#  ('greatest', 706),
#  ('care', 706),
#  ('thriller', 704),
#  ('tells', 704),
#  ('mean', 700),
#  ('o', 700),
#  ('self', 700),
#  ('etc', 699),
#  ('english', 699),
#  ('violence', 699),
#  ('run', 698),
#  ('totally', 698),
#  ('leave', 696),
#  ('important', 696),
#  ('wanted', 696),
#  ('heard', 694),
#  ('change', 691),
#  ('comic', 688),
#  ('career', 688),
#  ('british', 686),
#  ('eye', 685),
#  ('miss', 682),
#  ('usual', 681),
#  ('starts', 681),
#  ('robert', 678),
#  ('country', 677),
#  ('power', 671),
#  ('guys', 671),
#  ('television', 668),
#  ('opinion', 666),
#  ('girls', 665),
#  ('realistic', 663),
#  ('atmosphere', 663),
#  ('god', 662),
#  ('hero', 662),
#  ('rock', 662),
#  ('animation', 659),
#  ('york', 656),
#  ('extremely', 656),
#  ('novel', 655),
#  ('easy', 654),
#  ('kid', 653),
#  ('says', 652),
#  ('attention', 652),
#  ('problem', 651),
#  ('writing', 647),
#  ('class', 647),
#  ('alone', 646),
#  ('french', 646),
#  ('act', 645),
#  ('stuff', 643),
#  ('ones', 641),
#  ('seemed', 640),
#  ('tale', 640),
#  ('writer', 637),
#  ('famous', 633),
#  ('strange', 632),
#  ('beauty', 628),
#  ('involved', 624),
#  ('sequence', 624),
#  ('taken', 623),
#  ('happened', 622),
#  ('wish', 621),
#  ('knows', 621),
#  ('serious', 620),
#  ('opening', 620),
#  ('songs', 618),
#  ('kill', 617),
#  ('tony', 617),
#  ('cool', 616),
#  ('cannot', 616),
#  ('lady', 614),
#  ('room', 611),
#  ('team', 611),
#  ('order', 611),
#  ('begins', 611),
#  ('theme', 611),
#  ('taking', 610),
#  ('b', 608),
#  ('exactly', 607),
#  ('herself', 607),
#  ('four', 606),
#  ('due', 605),
#  ('happen', 605),
#  ('car', 605),
#  ('ways', 604),
#  ('perfectly', 604),
#  ('surprised', 603),
#  ('george', 602),
#  ('sets', 602),
#  ('anyway', 602),
#  ('myself', 600),
#  ('sad', 599),
#  ('memorable', 598),
#  ('similar', 598),
#  ('tries', 597),
#  ('easily', 596),
#  ('crime', 595),
#  ('level', 594),
#  ('brought', 594),
#  ('powerful', 594),
#  ('society', 593),
#  ('across', 593),
#  ('among', 592),
#  ('jane', 592),
#  ('release', 591),
#  ('slow', 590),
#  ('entertainment', 589),
#  ('form', 589),
#  ('message', 589),
#  ('red', 589),
#  ('believable', 588),
#  ('thinking', 586),
#  ('unique', 584),
#  ('upon', 582),
#  ('problems', 580),
#  ('interest', 580),
#  ('meets', 579),
#  ('viewers', 578),
#  ('stop', 576),
#  ('knew', 575),
#  ('joe', 575),
#  ('parents', 572),
#  ('usually', 572),
#  ('viewing', 572),
#  ('romance', 571),
#  ('nature', 570),
#  ('ends', 570),
#  ('possible', 568),
#  ('flick', 567),
#  ('richard', 567),
#  ('whether', 566),
#  ('certain', 565),
#  ('happens', 564),
#  ('above', 564),
#  ('mostly', 564),
#  ('local', 562),
#  ('th', 562),
#  ('working', 561),
#  ('bring', 561),
#  ('blood', 561),
#  ('peter', 560),
#  ('killed', 559),
#  ('mystery', 559),
#  ('middle', 559),
#  ('emotional', 558),
#  ('within', 558),
#  ('dance', 555),
#  ('sister', 555),
#  ('follow', 555),
#  ('couldn', 555),
#  ('de', 555),
#  ('major', 551),
#  ('haven', 551),
#  ('soundtrack', 550),
#  ('group', 549),
#  ('started', 549),
#  ('guess', 548),
#  ('words', 546),
#  ('talent', 545),
#  ('elements', 545),
#  ('leads', 545),
#  ('personal', 544),
#  ('named', 543),
#  ('period', 543),
#  ('needs', 543),
#  ('fantasy', 542),
#  ('obviously', 542),
#  ('masterpiece', 537),
#  ('stand', 536),
#  ('yourself', 536),
#  ('typical', 535),
#  ('deal', 534),
#  ('earth', 532),
#  ('truth', 532),
#  ('running', 529),
#  ('fast', 528),
#  ('brings', 528),
#  ('showing', 528),
#  ('huge', 528),
#  ('unfortunately', 527),
#  ('stage', 525),
#  ('turned', 525),
#  ('particular', 524),
#  ('disney', 524),
#  ('poor', 523),
#  ('five', 522),
#  ('dream', 522),
#  ('feature', 521),
#  ('body', 521),
#  ('incredible', 520),
#  ('america', 520),
#  ('near', 518),
#  ('hour', 518),
#  ('rating', 518),
#  ('obvious', 517),
#  ('deep', 517),
#  ('cut', 516),
#  ('indeed', 516),
#  ('nearly', 516),
#  ('became', 515),
#  ('giving', 513),
#  ('surprise', 513),
#  ('street', 512),
#  ('clear', 512),
#  ('match', 512),
#  ('learn', 512),
#  ('era', 509),
#  ('tom', 508),
#  ('female', 506),
#  ('buy', 505),
#  ('meet', 503),
#  ('hell', 502),
#  ('japanese', 502),
#  ('hours', 501),
#  ('sweet', 501),
#  ('feels', 500),
#  ('clearly', 500),
#  ('lots', 500),
#  ('comments', 499),
#  ('means', 499),
#  ('suspense', 498),
#  ('sequences', 495),
#  ('situation', 493),
#  ('talking', 493),
#  ('recommended', 493),
#  ('complete', 492),
#  ('creepy', 491),
#  ('eventually', 490),
#  ('except', 490),
#  ('note', 488),
#  ('ten', 486),
#  ('baby', 486),
#  ('william', 485),
#  ('filmed', 485),
#  ('keeps', 485),
#  ('unlike', 484),
#  ('gone', 484),
#  ('fall', 483),
#  ('shots', 483),
#  ('fi', 483),
#  ('check', 483),
#  ('sci', 480),
#  ('forget', 479),
#  ('general', 479),
#  ('scary', 478),
#  ('appears', 478),
#  ('present', 477),
#  ('beyond', 477),
#  ('talk', 476),
#  ('plenty', 474),
#  ('dramatic', 473),
#  ('whom', 472),
#  ('older', 472),
#  ('doubt', 470),
#  ('using', 468),
#  ('bill', 468),
#  ('hear', 467),
#  ('adventure', 467),
#  ('earlier', 467),
#  ('wonder', 464),
#  ('add', 463),
#  ('recently', 463),
#  ('portrayal', 462),
#  ('move', 461),
#  ('leaves', 461),
#  ('solid', 461),
#  ('word', 461),
#  ('married', 461),
#  ('difficult', 461),
#  ('business', 461),
#  ('subject', 460),
#  ('oh', 459),
#  ('beautifully', 459),
#  ('single', 458),
#  ('theater', 458),
#  ('space', 457),
#  ('third', 456),
#  ('setting', 456),
#  ('falls', 455),
#  ('jim', 455),
#  ('call', 451),
#  ('dog', 450),
#  ('jokes', 449),
#  ('portrayed', 449),
#  ('return', 449),
#  ('outstanding', 448),
#  ('awesome', 448),
#  ('straight', 448),
#  ('please', 447),
#  ('interested', 447),
#  ('decent', 447),
#  ('features', 446),
#  ('spirit', 446),
#  ('sees', 445),
#  ('davis', 445),
#  ('wouldn', 444),
#  ('points', 443),
#  ('towards', 443),
#  ('figure', 443),
#  ('touching', 442),
#  ('success', 442),
#  ('lee', 442),
#  ('leading', 441),
#  ('terrific', 441),
#  ('non', 441),
#  ('lack', 441),
#  ('effective', 440),
#  ('battle', 440),
#  ('screenplay', 439),
#  ('die', 439),
#  ('political', 439),
#  ('various', 438),
#  ('kelly', 438),
#  ('actual', 437),
#  ('boys', 436),
#  ('social', 435),
#  ('brothers', 435),
#  ('sexual', 434),
#  ('hate', 434),
#  ('impressive', 433),
#  ('caught', 433),
#  ('rich', 432),
#  ('acted', 431),
#  ('disappointed', 430),
#  ('aren', 430),
#  ('dr', 427),
#  ('mark', 427),
#  ('moves', 424),
#  ('reading', 423),
#  ('inside', 423),
#  ('pace', 423),
#  ('boring', 422),
#  ('manages', 422),
#  ('popular', 420),
#  ('subtle', 420),
#  ('none', 419),
#  ('effect', 419),
#  ('realize', 419),
#  ('review', 418),
#  ('visual', 418),
#  ('smith', 418),
#  ('created', 418),
#  ('familiar', 417),
#  ('magic', 417),
#  ('noir', 417),
#  ('looked', 416),
#  ('material', 416),
#  ('intelligent', 415),
#  ('background', 414),
#  ('western', 414),
#  ('animated', 414),
#  ('charming', 414),
#  ('create', 413),
#  ('deserves', 413),
#  ('supposed', 412),
#  ('stewart', 412),
#  ('crazy', 412),
#  ('directors', 411),
#  ('rate', 411),
#  ('century', 411),
#  ('appreciate', 410),
#  ('open', 410),
#  ('language', 408),
#  ('mention', 408),
#  ('copy', 408),
#  ('plus', 407),
#  ('telling', 407),
#  ('master', 406),
#  ('male', 406),
#  ('secret', 405),
#  ('hot', 405),
#  ('stunning', 405),
#  ('edge', 404),
#  ('rare', 404),
#  ('basically', 404),
#  ('kept', 403),
#  ('ben', 403),
#  ('pure', 402),
#  ('storyline', 401),
#  ('uses', 401),
#  ('saying', 400),
#  ('expected', 400),
#  ('free', 400),
#  ('public', 400),
#  ('somehow', 400),
#  ('themes', 400),
#  ('mary', 399),
#  ('recent', 398),
#  ('co', 398),
#  ('quickly', 398),
#  ('natural', 398),
#  ('cold', 397),
#  ('complex', 397),
#  ('air', 397),
#  ('imagine', 397),
#  ('hands', 396),
#  ('ok', 396),
#  ('seriously', 396),
#  ('stay', 395),
#  ('question', 394),
#  ('escape', 394),
#  ('exciting', 394),
#  ('surprisingly', 394),
#  ('dancing', 394),
#  ('harry', 394),
#  ('apart', 393),
#  ('office', 393),
#  ('thanks', 392),
#  ('touch', 391),
#  ('wait', 391),
#  ('welles', 391),
#  ('average', 390),
#  ('following', 390),
#  ('adult', 390),
#  ('singing', 390),
#  ('gore', 389),
#  ('odd', 388),
#  ('needed', 388),
#  ('worked', 387),
#  ('journey', 387),
#  ('filled', 386),
#  ('attempt', 385),
#  ('reviews', 384),
#  ('hold', 384),
#  ('outside', 382),
#  ('lovely', 380),
#  ('minute', 380),
#  ('missed', 380),
#  ('italian', 380),
#  ('successful', 378),
#  ('members', 377),
#  ('paris', 377),
#  ('studio', 377),
#  ('reasons', 377),
#  ('images', 376),
#  ('law', 376),
#  ('former', 375),
#  ('editing', 374),
#  ('large', 374),
#  ('prison', 374),
#  ('water', 373),
#  ('fairly', 372),
#  ('bruce', 372),
#  ('admit', 371),
#  ('break', 371),
#  ('emotions', 371),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 703545),
#  ('.', 210890),
#  ('the', 204884),
#  ('a', 99272),
#  ('and', 93196),
#  ('to', 86631),
#  ('of', 86412),
#  ('br', 65895),
#  ('is', 62926),
#  ('it', 60494),
#  ('i', 59128),
#  ('in', 54811),
#  ('this', 51314),
#  ('that', 47196),
#  ('s', 39471),
#  ('was', 33068),
#  ('movie', 31483),
#  ('for', 27427),
#  ('but', 27325),
#  ('with', 26235),
#  ('as', 25924),
#  ('t', 25517),
#  ('film', 23943),
#  ('you', 21947),
#  ('on', 21581),
#  ('not', 20608),
#  ('have', 19051),
#  ('are', 18362),
#  ('be', 18262),
#  ('he', 17202),
#  ('one', 16497),
#  ('they', 16335),
#  ('at', 15417),
#  ('his', 15190),
#  ('all', 15172),
#  ('so', 14513),
#  ('like', 14067),
#  ('there', 13401),
#  ('by', 13199),
#  ('just', 13193),
#  ('an', 12963),
#  ('or', 12914),
#  ('who', 12460),
#  ('from', 12134),
#  ('if', 11915),
#  ('about', 11311),
#  ('out', 11224),
#  ('what', 10599),
#  ('some', 10343),
#  ('no', 10178),
#  ('her', 9993),
#  ('even', 9629),
#  ('can', 9626),
#  ('has', 9515),
#  ('good', 9370),
#  ('bad', 9352),
#  ('would', 8952),
#  ('up', 8728),
#  ('only', 8595),
#  ('more', 8512),
#  ('when', 8437),
#  ('she', 8162),
#  ('time', 7892),
#  ('really', 7793),
#  ('had', 7750),
#  ('my', 7622),
#  ('were', 7599),
#  ('very', 7306),
#  ('which', 7213),
#  ('me', 7016),
#  ('see', 6850),
#  ('don', 6672),
#  ('we', 6623),
#  ('their', 6614),
#  ('do', 6561),
#  ('story', 6522),
#  ('than', 6437),
#  ('much', 6427),
#  ('been', 6337),
#  ('get', 6302),
#  ('because', 6215),
#  ('people', 5969),
#  ('then', 5946),
#  ('make', 5922),
#  ('how', 5919),
#  ('could', 5912),
#  ('any', 5868),
#  ('into', 5677),
#  ('made', 5674),
#  ('first', 5401),
#  ('well', 5354),
#  ('other', 5313),
#  ('them', 5280),
#  ('plot', 5213),
#  ('too', 5206),
#  ('acting', 5134),
#  ('will', 5117),
#  ('movies', 5109),
#  ('way', 5022),
#  ('most', 4947),
#  ('after', 4820),
#  ('him', 4816),
#  ('think', 4608),
#  ('its', 4570),
#  ('characters', 4533),
#  ('also', 4476),
#  ('off', 4462),
#  ('did', 4454),
#  ('watch', 4449),
#  ('character', 4389),
#  ('why', 4349),
#  ('being', 4237),
#  ('better', 4207),
#  ('know', 4155),
#  ('seen', 4121),
#  ('never', 4121),
#  ('over', 4107),
#  ('where', 4094),
#  ('ever', 4079),
#  ('your', 4076),
#  ('two', 3946),
#  ('little', 3896),
#  ('films', 3876),
#  ('nothing', 3770),
#  ('say', 3756),
#  ('m', 3752),
#  ('here', 3747),
#  ('end', 3698),
#  ('many', 3675),
#  ('should', 3658),
#  ('something', 3615),
#  ('thing', 3589),
#  ('does', 3588),
#  ('scene', 3561),
#  ('show', 3556),
#  ('scenes', 3531),
#  ('ve', 3511),
#  ('these', 3503),
#  ('go', 3415),
#  ('didn', 3369),
#  ('great', 3345),
#  ('watching', 3291),
#  ('re', 3273),
#  ('doesn', 3270),
#  ('through', 3209),
#  ('such', 3171),
#  ('worst', 3152),
#  ('actors', 3131),
#  ('man', 3117),
#  ('while', 3105),
#  ('back', 3053),
#  ('director', 3034),
#  ('life', 3021),
#  ('actually', 3013),
#  ('going', 2927),
#  ('funny', 2919),
#  ('now', 2863),
#  ('look', 2850),
#  ('still', 2823),
#  ('those', 2795),
#  ('another', 2786),
#  ('old', 2736),
#  ('real', 2725),
#  ('before', 2704),
#  ('few', 2693),
#  ('minutes', 2690),
#  ('want', 2688),
#  ('love', 2685),
#  ('pretty', 2676),
#  ('same', 2674),
#  ('horror', 2638),
#  ('though', 2602),
#  ('best', 2601),
#  ('script', 2595),
#  ('work', 2538),
#  ('every', 2536),
#  ('least', 2492),
#  ('enough', 2486),
#  ('down', 2484),
#  ('seems', 2471),
#  ('guy', 2452),
#  ('got', 2443),
#  ('part', 2437),
#  ('around', 2422),
#  ('original', 2386),
#  ('find', 2373),
#  ('anything', 2347),
#  ('lot', 2343),
#  ('point', 2335),
#  ('things', 2333),
#  ('fact', 2321),
#  ('new', 2317),
#  ('again', 2311),
#  ('give', 2297),
#  ('take', 2282),
#  ('isn', 2279),
#  ('d', 2272),
#  ('thought', 2246),
#  ('years', 2240),
#  ('makes', 2237),
#  ('whole', 2198),
#  ('long', 2192),
#  ('however', 2177),
#  ('making', 2147),
#  ('cast', 2144),
#  ('gets', 2110),
#  ('big', 2099),
#  ('might', 2088),
#  ('money', 2083),
#  ('interesting', 2072),
#  ('action', 2071),
#  ('far', 2045),
#  ('right', 2039),
#  ('without', 2025),
#  ('come', 2020),
#  ('almost', 2007),
#  ('us', 1996),
#  ('quite', 1988),
#  ('awful', 1985),
#  ('ll', 1967),
#  ('kind', 1941),
#  ('done', 1934),
#  ('reason', 1930),
#  ('am', 1917),
#  ('must', 1916),
#  ('boring', 1902),
#  ('looks', 1897),
#  ('someone', 1878),
#  ('instead', 1875),
#  ('trying', 1869),
#  ('comedy', 1868),
#  ('away', 1864),
#  ('poor', 1850),
#  ('wasn', 1850),
#  ('saw', 1849),
#  ('probably', 1842),
#  ('girl', 1813),
#  ('believe', 1804),
#  ('looking', 1790),
#  ('terrible', 1786),
#  ('maybe', 1783),
#  ('since', 1782),
#  ('sure', 1778),
#  ('world', 1775),
#  ('last', 1771),
#  ('anyone', 1770),
#  ('stupid', 1765),
#  ('let', 1753),
#  ('tv', 1743),
#  ('woman', 1742),
#  ('hard', 1741),
#  ('times', 1740),
#  ('may', 1729),
#  ('waste', 1728),
#  ('between', 1722),
#  ('rather', 1718),
#  ('feel', 1692),
#  ('effects', 1689),
#  ('book', 1670),
#  ('half', 1666),
#  ('own', 1651),
#  ('idea', 1645),
#  ('music', 1637),
#  ('young', 1636),
#  ('sense', 1609),
#  ('bit', 1593),
#  ('having', 1590),
#  ('found', 1587),
#  ('series', 1584),
#  ('put', 1583),
#  ('worse', 1578),
#  ('role', 1558),
#  ('goes', 1555),
#  ('said', 1552),
#  ('comes', 1538),
#  ('main', 1531),
#  ('screen', 1527),
#  ('everything', 1527),
#  ('audience', 1520),
#  ('ending', 1509),
#  ('else', 1497),
#  ('actor', 1492),
#  ('either', 1491),
#  ('family', 1481),
#  ('low', 1480),
#  ('yet', 1478),
#  ('budget', 1476),
#  ('set', 1472),
#  ('both', 1467),
#  ('always', 1465),
#  ('supposed', 1462),
#  ('completely', 1455),
#  ('left', 1446),
#  ('wrong', 1442),
#  ('seem', 1428),
#  ('course', 1425),
#  ('watched', 1419),
#  ('place', 1417),
#  ('shot', 1416),
#  ('simply', 1413),
#  ('day', 1406),
#  ('mean', 1400),
#  ('special', 1389),
#  ('read', 1376),
#  ('three', 1365),
#  ('house', 1354),
#  ('year', 1343),
#  ('horrible', 1342),
#  ('night', 1342),
#  ('once', 1331),
#  ('less', 1329),
#  ('dead', 1327),
#  ('high', 1323),
#  ('black', 1322),
#  ('couldn', 1318),
#  ('worth', 1318),
#  ('oh', 1316),
#  ('camera', 1316),
#  ('try', 1315),
#  ('line', 1306),
#  ('although', 1299),
#  ('our', 1295),
#  ('rest', 1273),
#  ('played', 1271),
#  ('seeing', 1267),
#  ('sex', 1266),
#  ('production', 1263),
#  ('dvd', 1261),
#  ('video', 1258),
#  ('fun', 1256),
#  ('everyone', 1254),
#  ('american', 1254),
#  ('mind', 1243),
#  ('play', 1240),
#  ('women', 1235),
#  ('during', 1231),
#  ('together', 1229),
#  ('version', 1224),
#  ('given', 1222),
#  ('kids', 1221),
#  ('tell', 1218),
#  ('second', 1214),
#  ('used', 1214),
#  ('performance', 1213),
#  ('wife', 1198),
#  ('especially', 1193),
#  ('dialogue', 1188),
#  ('need', 1188),
#  ('takes', 1187),
#  ('star', 1180),
#  ('use', 1179),
#  ('start', 1178),
#  ('lines', 1171),
#  ('each', 1170),
#  ('doing', 1168),
#  ('couple', 1166),
#  ('getting', 1161),
#  ('unfortunately', 1157),
#  ('problem', 1152),
#  ('crap', 1149),
#  ('himself', 1148),
#  ('death', 1136),
#  ('guess', 1136),
#  ('name', 1127),
#  ('fan', 1124),
#  ('help', 1123),
#  ('killer', 1122),
#  ('piece', 1120),
#  ('head', 1113),
#  ('entire', 1107),
#  ('home', 1103),
#  ('different', 1101),
#  ('hollywood', 1099),
#  ('short', 1095),
#  ('nice', 1094),
#  ('john', 1080),
#  ('seemed', 1079),
#  ('later', 1072),
#  ('next', 1071),
#  ('person', 1070),
#  ('understand', 1065),
#  ('absolutely', 1064),
#  ('sort', 1063),
#  ('true', 1061),
#  ('felt', 1048),
#  ('shows', 1046),
#  ('written', 1043),
#  ('school', 1042),
#  ('job', 1040),
#  ('care', 1038),
#  ('men', 1036),
#  ('plays', 1035),
#  ('stars', 1026),
#  ('until', 1021),
#  ('case', 1019),
#  ('face', 1019),
#  ('flick', 1018),
#  ('went', 1016),
#  ('decent', 1014),
#  ('yes', 1009),
#  ('along', 1008),
#  ('called', 1005),
#  ('perhaps', 1001),
#  ('full', 998),
#  ('title', 995),
#  ('itself', 995),
#  ('writing', 995),
#  ('came', 994),
#  ('evil', 991),
#  ('top', 989),
#  ('friends', 986),
#  ('hour', 983),
#  ('laugh', 983),
#  ('annoying', 981),
#  ('guys', 977),
#  ('wanted', 975),
#  ('ridiculous', 974),
#  ('tries', 974),
#  ('totally', 968),
#  ('obviously', 957),
#  ('keep', 954),
#  ('direction', 953),
#  ('save', 947),
#  ('won', 947),
#  ('thinking', 945),
#  ('playing', 945),
#  ('sound', 942),
#  ('car', 942),
#  ('blood', 937),
#  ('example', 934),
#  ('already', 934),
#  ('except', 934),
#  ('lost', 931),
#  ('god', 930),
#  ('act', 930),
#  ('attempt', 925),
#  ('ok', 920),
#  ('kill', 918),
#  ('b', 910),
#  ('truly', 909),
#  ('war', 907),
#  ('style', 902),
#  ('remember', 902),
#  ('gore', 899),
#  ('turn', 898),
#  ('white', 894),
#  ('moments', 890),
#  ('please', 887),
#  ('dull', 885),
#  ('father', 884),
#  ('finally', 880),
#  ('lack', 873),
#  ('cheap', 869),
#  ('recommend', 863),
#  ('wouldn', 862),
#  ('enjoy', 861),
#  ('quality', 861),
#  ('boy', 858),
#  ('looked', 858),
#  ('starts', 851),
#  ('run', 851),
#  ('children', 850),
#  ('kid', 848),
#  ('hell', 848),
#  ('lead', 843),
#  ('hand', 840),
#  ('seriously', 839),
#  ('wonder', 839),
#  ('hope', 838),
#  ('stuff', 837),
#  ('none', 836),
#  ('beginning', 835),
#  ('myself', 834),
#  ('etc', 832),
#  ('obvious', 831),
#  ('under', 830),
#  ('slow', 829),
#  ('behind', 828),
#  ('killed', 825),
#  ('against', 822),
#  ('lame', 821),
#  ('others', 821),
#  ('girls', 817),
#  ('complete', 817),
#  ('picture', 816),
#  ('small', 812),
#  ('becomes', 810),
#  ('become', 809),
#  ('despite', 807),
#  ('fans', 806),
#  ('episode', 806),
#  ('mother', 804),
#  ('poorly', 802),
#  ('cut', 801),
#  ('apparently', 801),
#  ('writer', 799),
#  ('happens', 797),
#  ('early', 797),
#  ('based', 795),
#  ('anyway', 794),
#  ('cannot', 794),
#  ('self', 793),
#  ('gave', 792),
#  ('several', 791),
#  ('certainly', 791),
#  ('live', 791),
#  ('avoid', 790),
#  ('close', 786),
#  ('saying', 785),
#  ('predictable', 784),
#  ('classic', 780),
#  ('silly', 775),
#  ('human', 774),
#  ('often', 773),
#  ('jokes', 768),
#  ('stop', 768),
#  ('happened', 759),
#  ('expect', 752),
#  ('friend', 752),
#  ('mr', 749),
#  ('liked', 748),
#  ('entertaining', 747),
#  ('scary', 747),
#  ('wants', 744),
#  ('actress', 743),
#  ('cinema', 743),
#  ('overall', 742),
#  ('performances', 741),
#  ('daughter', 738),
#  ('child', 738),
#  ('beautiful', 736),
#  ('call', 731),
#  ('days', 731),
#  ('eyes', 731),
#  ('themselves', 730),
#  ('directed', 729),
#  ('bunch', 728),
#  ('fight', 728),
#  ('badly', 727),
#  ('interest', 727),
#  ('final', 723),
#  ('humor', 720),
#  ('involved', 719),
#  ('art', 719),
#  ('hours', 715),
#  ('heard', 715),
#  ('running', 713),
#  ('says', 711),
#  ('disappointed', 710),
#  ('turns', 710),
#  ('sorry', 708),
#  ('happen', 708),
#  ('basically', 706),
#  ('viewer', 702),
#  ('body', 701),
#  ('side', 695),
#  ('yourself', 693),
#  ('alone', 693),
#  ('started', 692),
#  ('throughout', 691),
#  ('word', 691),
#  ('violence', 691),
#  ('shots', 690),
#  ('possible', 689),
#  ('weak', 688),
#  ('single', 688),
#  ('gives', 685),
#  ('police', 685),
#  ('leave', 685),
#  ('group', 684),
#  ('turned', 683),
#  ('rating', 682),
#  ('hero', 681),
#  ('parts', 681),
#  ('talking', 679),
#  ('dark', 679),
#  ('michael', 678),
#  ('extremely', 678),
#  ('type', 677),
#  ('non', 676),
#  ('mess', 676),
#  ('took', 674),
#  ('drama', 673),
#  ('review', 673),
#  ('game', 673),
#  ('able', 672),
#  ('past', 671),
#  ('usually', 671),
#  ('unless', 670),
#  ('matter', 665),
#  ('aren', 664),
#  ('definitely', 663),
#  ('exactly', 660),
#  ('talent', 660),
#  ('son', 659),
#  ('female', 659),
#  ('effort', 658),
#  ('tried', 657),
#  ('cool', 655),
#  ('voice', 653),
#  ('zombie', 653),
#  ('feeling', 646),
#  ('middle', 643),
#  ('soon', 643),
#  ('ends', 642),
#  ('serious', 638),
#  ('sequel', 637),
#  ('huge', 636),
#  ('genre', 636),
#  ('major', 635),
#  ('history', 634),
#  ('stories', 632),
#  ('beyond', 627),
#  ('town', 625),
#  ('level', 623),
#  ('coming', 623),
#  ('opening', 622),
#  ('straight', 622),
#  ('wasted', 621),
#  ('rent', 621),
#  ('earth', 620),
#  ('particularly', 618),
#  ('five', 616),
#  ('dialog', 614),
#  ('mostly', 611),
#  ('order', 610),
#  ('lives', 608),
#  ('sad', 608),
#  ('joke', 608),
#  ('moment', 606),
#  ('taken', 605),
#  ('minute', 604),
#  ('editing', 603),
#  ('clearly', 603),
#  ('premise', 600),
#  ('hit', 599),
#  ('lee', 599),
#  ('fast', 595),
#  ('stay', 594),
#  ('late', 594),
#  ('okay', 594),
#  ('across', 593),
#  ('falls', 590),
#  ('dumb', 588),
#  ('talk', 587),
#  ('theater', 586),
#  ('wish', 585),
#  ('fails', 585),
#  ('mention', 585),
#  ('fine', 584),
#  ('known', 583),
#  ('storyline', 582),
#  ('whatever', 581),
#  ('write', 581),
#  ('pointless', 580),
#  ('die', 579),
#  ('words', 577),
#  ('husband', 577),
#  ('room', 572),
#  ('appears', 572),
#  ('ten', 572),
#  ('chance', 572),
#  ('sometimes', 571),
#  ('taking', 568),
#  ('killing', 568),
#  ('four', 566),
#  ('sit', 565),
#  ('career', 563),
#  ('novel', 562),
#  ('murder', 561),
#  ('english', 558),
#  ('shown', 555),
#  ('told', 555),
#  ('total', 554),
#  ('ones', 554),
#  ('using', 553),
#  ('problems', 546),
#  ('actual', 546),
#  ('monster', 545),
#  ('somehow', 545),
#  ('imdb', 545),
#  ('easily', 545),
#  ('power', 544),
#  ('possibly', 542),
#  ('living', 542),
#  ('giving', 541),
#  ('brother', 540),
#  ('due', 540),
#  ('roles', 540),
#  ('imagine', 538),
#  ('works', 535),
#  ('add', 534),
#  ('strange', 533),
#  ('points', 533),
#  ('reviews', 533),
#  ('local', 533),
#  ('knew', 531),
#  ('material', 531),
#  ('flat', 531),
#  ('opinion', 531),
#  ('space', 531),
#  ('usual', 530),
#  ('experience', 528),
#  ('number', 528),
#  ('kept', 528),
#  ('including', 527),
#  ('otherwise', 526),
#  ('city', 526),
#  ('somewhat', 526),
#  ('hate', 526),
#  ('cheesy', 525),
#  ('nudity', 524),
#  ('age', 524),
#  ('near', 523),
#  ('cop', 523),
#  ('feels', 522),
#  ('ago', 520),
#  ('decided', 520),
#  ('king', 519),
#  ('plain', 516),
#  ('change', 516),
#  ('shame', 515),
#  ('needs', 514),
#  ('upon', 514),
#  ('credits', 513),
#  ('expected', 511),
#  ('writers', 511),
#  ('doubt', 510),
#  ('lots', 509),
#  ('class', 509),
#  ('score', 509),
#  ('whether', 509),
#  ('comments', 508),
#  ('free', 506),
#  ('nor', 505),
#  ('cinematography', 504),
#  ('bring', 503),
#  ('nearly', 503),
#  ('knows', 503),
#  ('wait', 503),
#  ('lady', 503),
#  ('entertainment', 502),
#  ('songs', 502),
#  ('laughable', 502),
#  ('excellent', 501),
#  ('bored', 501),
#  ('sets', 501),
#  ('james', 497),
#  ('whose', 496),
#  ('general', 493),
#  ('average', 493),
#  ('figure', 492),
#  ('o', 492),
#  ('forced', 492),
#  ('pathetic', 491),
#  ('footage', 490),
#  ('song', 490),
#  ('documentary', 488),
#  ('zombies', 488),
#  ('view', 486),
#  ('released', 486),
#  ('check', 485),
#  ('george', 484),
#  ('above', 484),
#  ('ask', 484),
#  ('within', 483),
#  ('needed', 482),
#  ('potential', 481),
#  ('development', 480),
#  ('important', 480),
#  ('buy', 480),
#  ('male', 479),
#  ('robert', 478),
#  ('hot', 478),
#  ('light', 477),
#  ('stand', 477),
#  ('attention', 475),
#  ('clear', 474),
#  ('comic', 473),
#  ('directing', 473),
#  ('sequence', 472),
#  ('gone', 472),
#  ('mystery', 471),
#  ('means', 470),
#  ('garbage', 470),
#  ('begin', 470),
#  ('message', 469),
#  ('heart', 469),
#  ('box', 469),
#  ('thriller', 468),
#  ('hear', 468),
#  ('david', 466),
#  ('perfect', 465),
#  ('country', 464),
#  ('fall', 464),
#  ('pay', 463),
#  ('trash', 463),
#  ('spent', 463),
#  ('laughs', 462),
#  ('third', 461),
#  ('filmed', 460),
#  ('fake', 460),
#  ('forward', 458),
#  ('reading', 458),
#  ('television', 458),
#  ('reality', 458),
#  ('forget', 457),
#  ('eye', 457),
#  ('musical', 457),
#  ('suspense', 456),
#  ('enjoyed', 456),
#  ('incredibly', 456),
#  ('hilarious', 456),
#  ('move', 456),
#  ('cover', 454),
#  ('directors', 453),
#  ('happy', 453),
#  ('filmmakers', 453),
#  ('sister', 453),
#  ('gay', 452),
#  ('sounds', 452),
#  ('showing', 451),
#  ('remake', 451),
#  ('haven', 450),
#  ('sequences', 450),
#  ('named', 450),
#  ('miss', 449),
#  ('british', 449),
#  ('similar', 447),
#  ('hardly', 446),
#  ('failed', 445),
#  ('comment', 445),
#  ('weird', 442),
#  ('red', 440),
#  ('sadly', 440),
#  ('screenplay', 439),
#  ('finds', 439),
#  ('richard', 438),
#  ('rock', 436),
#  ('baby', 436),
#  ('elements', 436),
#  ('question', 435),
#  ('worked', 435),
#  ('brain', 433),
#  ('air', 431),
#  ('typical', 431),
#  ('feature', 431),
#  ('island', 430),
#  ('spoilers', 430),
#  ('ideas', 428),
#  ('girlfriend', 428),
#  ('loved', 428),
#  ('attempts', 427),
#  ('neither', 427),
#  ('walk', 427),
#  ('modern', 427),
#  ('result', 427),
#  ('working', 427),
#  ('leads', 426),
#  ('events', 426),
#  ('plus', 426),
#  ('crazy', 425),
#  ('tom', 425),
#  ('producers', 424),
#  ('wrote', 424),
#  ('open', 424),
#  ('apart', 424),
#  ('gun', 424),
#  ('team', 424),
#  ('eventually', 423),
#  ('acted', 423),
#  ('bother', 422),
#  ('meant', 422),
#  ('barely', 421),
#  ('unbelievable', 420),
#  ('appear', 419),
#  ('fire', 419),
#  ('sexual', 419),
#  ('strong', 418),
#  ('theme', 418),
#  ('disappointing', 417),
#  ('excuse', 417),
#  ('follow', 415),
#  ('f', 414),
#  ('viewers', 414),
#  ('admit', 414),
#  ('e', 413),
#  ('concept', 412),
#  ('dog', 411),
#  ('herself', 410),
#  ('jack', 409),
#  ('weren', 408),
#  ('hands', 408),
#  ('learn', 407),
#  ('expecting', 407),
#  ('christmas', 407),
#  ('honestly', 405),
#  ('nowhere', 404),
#  ('tells', 404),
#  ('th', 404),
#  ('stick', 403),
#  ('twist', 403),
#  ('disappointment', 403),
#  ('kills', 403),
#  ('makers', 402),
#  ('release', 402),
#  ('subject', 401),
#  ('list', 401),
#  ('ended', 401),
#  ('realize', 399),
#  ('future', 398),
#  ('ways', 398),
#  ('simple', 398),
#  ('positive', 397),
#  ('difficult', 397),
#  ('previous', 397),
#  ('quickly', 397),
#  ('dr', 396),
#  ('shoot', 395),
#  ('surprise', 395),
#  ('spend', 394),
#  ('japanese', 394),
#  ('period', 392),
#  ('grade', 392),
#  ('among', 392),
#  ('yeah', 392),
#  ('peter', 392),
#  ('revenge', 392),
#  ('c', 391),
#  ('value', 391),
#  ('utterly', 390),
#  ('accent', 390),
#  ('villain', 390),
#  ('situation', 390),
#  ('note', 390),
#  ('suddenly', 389),
#  ('form', 388),
#  ('fi', 388),
#  ('redeeming', 388),
#  ('missing', 387),
#  ('america', 387),
#  ('soundtrack', 387),
#  ('casting', 387),
#  ('leaves', 386),
#  ('rate', 386),
#  ('begins', 385),
#  ('certain', 385),
#  ('break', 385),
#  ('today', 385),
#  ('street', 385),
#  ('sci', 384),
#  ('somewhere', 384),
#  ('truth', 383),
#  ('surprised', 383),
#  ('effect', 383),
#  ('slasher', 379),
#  ('bottom', 378),
#  ('front', 378),
#  ('outside', 378),
#  ('relationship', 378),
#  ('sick', 377),
#  ('painful', 376),
#  ('talented', 376),
#  ('doctor', 376),
#  ('create', 375),
#  ('project', 375),
#  ('earlier', 374),
#  ('biggest', 374),
#  ('van', 374),
#  ('considering', 373),
#  ('interested', 373),
#  ('crime', 373),
#  ('co', 372),
#  ('crew', 372),
#  ('york', 372),
#  ('mediocre', 372),
#  ('fighting', 372),
#  ('mark', 372),
#  ('reasons', 371),
#  ('wonderful', 371),
#  ('deal', 369),
#  ('indeed', 369),
#  ('hair', 368),
#  ('cause', 367),
#  ('computer', 366),
#  ('features', 366),
#  ('towards', 365),
#  ('fairly', 365),
#  ('credit', 365),
#  ('clich', 365),
#  ('parents', 364),
#  ('de', 364),
#  ('speak', 363),
#  ('mistake', 362),
#  ('became', 362),
#  ('odd', 361),
#  ('basic', 361),
#  ('creepy', 361),
#  ('particular', 360),
#  ('supporting', 359),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times

for word,count in total_counts.most_common():
    if count >= 100:
        pos_neg_ratios[word] = positive_counts[word] / (float(negative_counts[word] + 1))

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0712448446689606
# Pos-to-neg ratio for 'amazing' = 4.104294478527607
# Pos-to-neg ratio for 'terrible' = 0.182988248461108

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert their values using the following formulas:
# > * For any postive words, convert the ratio using `np.log(ratio)`
# > * For any negative words, convert the ratio using `-np.log(1/(ratio + 0.01))`
#
# That second equation may look strange, but what it's doing is dividing one by a very small number, which will produce a larger positive number. Then, it takes the `log` of that, which produces numbers similar to the ones for the postive words. Finally, we negate the values by adding that minus sign up front. In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but oppositite signs.

# %%
# TODO: Convert ratios to logs
for word, ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / (ratio+0.01)))

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.06882137847389518
# Pos-to-neg ratio for 'amazing' = 1.412033859321466
# Pos-to-neg ratio for 'terrible' = -1.645125980733599

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 5.3706380281276624),
#  ('goldsworthy', 4.8675344504555822),
#  ('visconti', 4.6051701859880918),
#  ('paulie', 4.1510399058986458),
#  ('lindy', 4.1108738641733114),
#  ('hayworth', 3.6018680771243066),
#  ('felix', 3.5600986642480112),
#  ('kolchak', 3.3945083935113587),
#  ('mildred', 3.2865344733420154),
#  ('ratso', 3.1640675883732059),
#  ('matthau', 3.1257854018021889),
#  ('sg', 3.0019628233046269),
#  ('rea', 2.9957322735539909),
#  ('cal', 2.9356283494842854),
#  ('polanski', 2.8810693652338513),
#  ('chamberlain', 2.8498803965414279),
#  ('cypher', 2.5649493574615367),
#  ('scoop', 2.5477075510270306),
#  ('gandhi', 2.5389738710582761),
#  ('wang', 2.529358412358834),
#  ('flawless', 2.5055259369907361),
#  ('raines', 2.4952694368235471),
#  ('kidman', 2.3642786619993856),
#  ('victoria', 2.3161293181018028),
#  ('christy', 2.3025850929940459),
#  ('perfection', 2.2727321298443646),
#  ('steele', 2.2512917986064953),
#  ('superbly', 2.248191020928247),
#  ('masterful', 2.1870722058722012),
#  ('welles', 2.1845179260671048),
#  ('stargate', 2.1768157057050121),
#  ('elvira', 2.1381668276926185),
#  ('voight', 2.1335087629501119),
#  ('powell', 2.1257656133540745),
#  ('montana', 2.1177604059819726),
#  ('lemmon', 2.1118068261818674),
#  ('astaire', 2.1041341542702074),
#  ('sopranos', 2.1041341542702074),
#  ('liu', 2.1019143975318944),
#  ('election', 2.0794415416798357),
#  ('buffalo', 2.0557250150625199),
#  ('shanghai', 2.010973742402375),
#  ('captures', 1.9799559904650303),
#  ('wonderfully', 1.9718108774874705),
#  ('andre', 1.936941479072553),
#  ('sentinel', 1.936941479072553),
#  ('breathtaking', 1.9136492868370918),
#  ('bakshi', 1.911718784307034),
#  ('neill', 1.9042374526547452),
#  ('brosnan', 1.9029851043382795),
#  ('loy', 1.8935421635379974),
#  ('delightful', 1.8870696490323797),
#  ('europa', 1.8382794848629478),
#  ('gripping', 1.8340618489187444),
#  ('collette', 1.824549292051046),
#  ('sullivan', 1.8199303461947514),
#  ('refreshing', 1.8191584434161694),
#  ('darren', 1.8137383759468304),
#  ('sadness', 1.80005827204275),
#  ('extraordinary', 1.7437502500416944),
#  ('underrated', 1.7400580948511646),
#  ('timeless', 1.7397031072720019),
#  ('andrews', 1.7298840655099674),
#  ('carrey', 1.7190001149456267),
#  ('beautifully', 1.7102096022639472),
#  ('dustin', 1.7047480922384253),
#  ('bourne', 1.6899767749181127),
#  ('unforgettable', 1.6739764335716716),
#  ('superb', 1.670681537674819),
#  ('soccer', 1.6665963262740489),
#  ('favorites', 1.6541380913520072),
#  ('delight', 1.6509869153469727),
#  ('ruth', 1.6486586255873816),
#  ('alison', 1.6363453653540248),
#  ('watson', 1.6326947745983675),
#  ('hartley', 1.6326947745983675),
#  ('palma', 1.6283063967384832),
#  ('lily', 1.6266797188686064),
#  ('lumet', 1.6211339521972916),
#  ('brilliantly', 1.6132043952295774),
#  ('friendship', 1.6094379124341003),
#  ('astonishing', 1.5976034547870976),
#  ('touching', 1.5915002117474331),
#  ('magnificent', 1.5907457794219477),
#  ('philip', 1.5797327580201845),
#  ('kurosawa', 1.5664205273504097),
#  ('simmons', 1.563975538357343),
#  ('bette', 1.552005863348225),
#  ('rita', 1.5493339883643948),
#  ('psychiatrist', 1.5429928130259476),
#  ('mamet', 1.5404450409471491),
#  ('hoffman', 1.5389241281064423),
#  ('wonderful', 1.532928382254783),
#  ('finest', 1.5327229948532388),
#  ('fantastic', 1.530875589930998),
#  ('orson', 1.5293952047605639),
#  ('titanic', 1.527817384079347),
#  ('terrific', 1.5246966839790097),
#  ('elegant', 1.5240780634829436),
#  ('macy', 1.5151272329628591),
#  ('ruby', 1.5088966832122228),
#  ('tender', 1.5040773967762742),
#  ('emma', 1.4984116592405967),
#  ('kline', 1.498212277323876),
#  ('tremendous', 1.492516574375198),
#  ('garbo', 1.4906543764441336),
#  ('april', 1.4894785973551214),
#  ('modesty', 1.4863778196768733),
#  ('hara', 1.483668525145067),
#  ('exceptional', 1.4802261809540942),
#  ('outstanding', 1.4798204191307143),
#  ('chilling', 1.4781019103730135),
#  ('stewart', 1.4777285670795224),
#  ('sidney', 1.4685324593568627),
#  ('pleasantly', 1.4635860354215371),
#  ('winters', 1.4632554022560189),
#  ('lincoln', 1.4579862895760072),
#  ('excellent', 1.4522947116703881),
#  ('unfolds', 1.451433663290852),
#  ('marvelous', 1.4500101755059984),
#  ('jackie', 1.4378280112350734),
#  ('brooklyn', 1.4350845252893227),
#  ('homer', 1.4288539755386864),
#  ('kelly', 1.418779816264379),
#  ('darker', 1.4180430594344708),
#  ('amazing', 1.4120338593214661),
#  ('seasons', 1.410986973710262),
#  ('uplifting', 1.4098248585300845),
#  ('overlooked', 1.4094614204014251),
#  ('flynn', 1.4081134085145304),
#  ('september', 1.4078005663408544),
#  ('splendid', 1.3943265328171548),
#  ('understated', 1.3862943611198906),
#  ('haunting', 1.3780638619833752),
#  ('draws', 1.3779261114493739),
#  ('sinatra', 1.3771618775566181),
#  ('widmark', 1.3705460041517514),
#  ('captivating', 1.3694872428035094),
#  ('mann', 1.3682758556172123),
#  ('cleverly', 1.3652409519220583),
#  ('chan', 1.363821505267832),
#  ('gem', 1.3612582829585658),
#  ('freedom', 1.3605418650174759),
#  ('portrait', 1.3528464270523506),
#  ('noir', 1.3509549946745818),
#  ('builds', 1.346448452572691),
#  ('thief', 1.3462890265061915),
#  ('innocence', 1.3325500851131999),
#  ('marie', 1.3261904370501851),
#  ('austen', 1.3261904370501851),
#  ('tony', 1.3250025960811893),
#  ('shines', 1.3217558399823195),
#  ('tends', 1.3188530803243581),
#  ('championship', 1.3188530803243581),
#  ('nancy', 1.3151984394361604),
#  ('barbara', 1.3110709398823031),
#  ('davis', 1.3105825393841943),
#  ('ensemble', 1.3083328196501789),
#  ('leo', 1.2858238307562562),
#  ('panic', 1.2845116668099483),
#  ('daniel', 1.2826159316450492),
#  ('rural', 1.2809338454620642),
#  ('hyde', 1.2809338454620642),
#  ('dickens', 1.2784053991087057),
#  ('fisher', 1.2776605201170952),
#  ('remarkable', 1.2748915310061018),
#  ('gentle', 1.2716314527997508),
#  ('brendan', 1.2685113254635072),
#  ('poignant', 1.2626804051527141),
#  ('ritter', 1.2616519159126141),
#  ('terrifying', 1.259880436264232),
#  ('stunning', 1.258954938743289),
#  ('conrad', 1.258954938743289),
#  ('favourite', 1.2543315962679946),
#  ('nominated', 1.2527629684953681),
#  ('vivid', 1.2527629684953681),
#  ('recommended', 1.2517492836645219),
#  ('brilliant', 1.2488944917174476),
#  ('holly', 1.2470322937863829),
#  ('glover', 1.2455944790167555),
#  ('powerful', 1.2452157628599851),
#  ('inspiring', 1.2452157628599851),
#  ('von', 1.2449402428141589),
#  ('favorite', 1.2423570473342513),
#  ('blake', 1.2417131323087831),
#  ('notch', 1.2373384981697364),
#  ('stanwyck', 1.2339536365378718),
#  ('perfect', 1.2260450076814351),
#  ('con', 1.2163953243244932),
#  ('vulnerable', 1.2150226405125208),
#  ('streep', 1.2147837204301515),
#  ('vengeance', 1.213923135179104),
#  ('ralph', 1.2136816184528969),
#  ('riveting', 1.2074151485169087),
#  ('burns', 1.2060982036382495),
#  ('gritty', 1.205666284832269),
#  ('davies', 1.2010272940961793),
#  ('stellar', 1.2007417837444896),
#  ('appreciated', 1.200394982978052),
#  ('rare', 1.1973938332278935),
#  ('troubled', 1.1968043148473233),
#  ('alexander', 1.1939224684724346),
#  ('smooth', 1.1848726329525165),
#  ('highly', 1.1788792367282792),
#  ('awesome', 1.1775395472577805),
#  ('viewings', 1.1727202608218317),
#  ('scarface', 1.1727202608218317),
#  ('joey', 1.1685708772750201),
#  ('contrast', 1.1679469820691739),
#  ('hong', 1.1653036631667819),
#  ('guilt', 1.1645702564599072),
#  ('june', 1.1631508098056809),
#  ('perfectly', 1.1618271828751725),
#  ('intense', 1.1588523690454664),
#  ('kung', 1.1585104302491787),
#  ('tragic', 1.1571806428191769),
#  ('loved', 1.1567199194753903),
#  ('bond', 1.1537987042354005),
#  ('ideal', 1.1526795099383853),
#  ('lukas', 1.1526795099383853),
#  ('sensitive', 1.1505720275988207),
#  ('courage', 1.1502842992124307),
#  ('dramas', 1.144074662744867),
#  ('cole', 1.1438688802562305),
#  ('waitress', 1.143563676530376),
#  ('today', 1.142538269125956),
#  ('daughters', 1.142506482225335),
#  ('carol', 1.1404593986036102),
#  ('dalton', 1.1349799328389845),
#  ('rose', 1.1345873911263875),
#  ('unique', 1.1334590199982777),
#  ('mistress', 1.1325138403437911),
#  ('fabulous', 1.1234582872546406),
#  ('warmth', 1.1213405397456659),
#  ('ned', 1.1201184938890731),
#  ('beatty', 1.1155618469818829),
#  ('elephant', 1.1151415906193203),
#  ('emotions', 1.1121810178741787),
#  ('crafted', 1.110882381259924),
#  ('bands', 1.1104467463151124),
#  ('ballet', 1.1080910326226534),
#  ('sandra', 1.1069110914828049),
#  ('essence', 1.1069110914828049),
#  ('depression', 1.106517468175223),
#  ('subtle', 1.1057807781467222),
#  ('hooked', 1.0986122886681098),
#  ('definite', 1.0986122886681098),
#  ('adorable', 1.0986122886681098),
#  ('provides', 1.0954626797652134),
#  ('louis', 1.0940356216406979),
#  ('eerie', 1.0913395293390298),
#  ('ann', 1.0908301482260547),
#  ('shelley', 1.087801372563894),
#  ('facing', 1.0874389880699844),
#  ('affect', 1.0870514662670339),
#  ('solo', 1.086636097621394),
#  ('anime', 1.0858732628906798),
#  ('nicole', 1.07880966137193),
#  ('carrie', 1.07880966137193),
#  ('inventive', 1.0775588794702773),
#  ('norman', 1.076139432816051),
#  ('greatest', 1.0748183040025869),
#  ('rival', 1.0721206732211332),
#  ('consequences', 1.0712133144799951),
#  ('beauty', 1.0672617587840336),
#  ('spy', 1.0661268335236214),
#  ('creates', 1.0647107369924282),
#  ('yeti', 1.0628942060660305),
#  ('warming', 0.63726672216548874),
#  ('imaginative', 0.63690746223706918),
#  ('french', 0.63598876671999671),
#  ('ride', 0.63499126040287124),
#  ('charismatic', 0.63405826418993882),
#  ('prisoners', 0.6332490389788763),
#  ('recognized', 0.63252255874351049),
#  ('challenging', 0.6317782341836532),
#  ('demands', 0.63127177684185776),
#  ('seeking', 0.63040883992652197),
#  ('morris', 0.63023335514937595),
#  ('plight', 0.63023335514937595),
#  ('kubrick', 0.62996827893841378),
#  ('award', 0.629325248489226),
#  ('nature', 0.62860865942237409),
#  ('anna', 0.62800787838898386),
#  ('greater', 0.62776442129709353),
#  ('bound', 0.62776442129709353),
#  ('keeping', 0.62747807705208802),
#  ('william', 0.62732082923794541),
#  ('underlying', 0.62689779501874465),
#  ('shine', 0.62570589976441282),
#  ('ultimate', 0.62548853208613053),
#  ('empire', 0.62482793658246816),
#  ('uncle', 0.62415430907299385),
#  ('rough', 0.62371867412818238),
#  ('millionaire', 0.623188591953035),
#  ('meeting', 0.62276638379814586),
#  ('nostalgic', 0.62252961334599188),
#  ('determined', 0.62219544458766085),
#  ('suspenseful', 0.62168821657780038),
#  ('performs', 0.62117368093485603),
#  ('instant', 0.62082651898031915),
#  ('brady', 0.62082651898031915),
#  ('brilliance', 0.62038782627751698),
#  ('paced', 0.61792375932235777),
#  ('aired', 0.61779774331815851),
#  ('variety', 0.61716127358202333),
#  ('secretary', 0.61651395453902935),
#  ('affected', 0.61576051694452505),
#  ('albeit', 0.61558894621407079),
#  ('inner', 0.61489498366019701),
#  ('discovers', 0.61467556511845012),
#  ('sunday', 0.61455690596672374),
#  ('jeff', 0.6141039732194925),
#  ('fine', 0.61402997040735185),
#  ('influenced', 0.61400986000122149),
#  ('lives', 0.6119406870285462),
#  ('julia', 0.61180154110599294),
#  ('academy', 0.61154853667706588),
#  ('brothers', 0.61151422606307404),
#  ('dawson', 0.6114691495456781),
#  ('capturing', 0.61090908232297314),
#  ('max', 0.61062615687194188),
#  ('elizabeth', 0.61056058955067127),
#  ('expressions', 0.61008058186133185),
#  ('williams', 0.60976557162089429),
#  ('charged', 0.60858979253188228),
#  ('melodrama', 0.6084059521048546),
#  ('images', 0.60657916425148639),
#  ('nine', 0.60613580357031549),
#  ('explore', 0.60613580357031549),
#  ('gift', 0.60613580357031549),
#  ('bernard', 0.60613580357031549),
#  ('retired', 0.60613580357031549),
#  ('providing', 0.60441906495126096),
#  ('ken', 0.60419969454344913),
#  ('famous', 0.60403164708645185),
#  ('jane', 0.60276311909167624),
#  ('presents', 0.60217540235421851),
#  ('introduces', 0.60217540235421851),
#  ('rob', 0.6019569424953487),
#  ('father', 0.60026343311727937),
#  ('voiced', 0.59911823091166894),
#  ('true', 0.59891927740644679),
#  ('fashioned', 0.59865633713902289),
#  ('tradition', 0.59783700075562041),
#  ('believable', 0.59598343210629756),
#  ('drew', 0.59470710774669278),
#  ('helping', 0.59470710774669278),
#  ('trio', 0.59470710774669278),
#  ('respected', 0.5937747067467416),
#  ('soviet', 0.59351733961110398),
#  ('charm', 0.55729649814433169),
#  ('neighbor', 0.55719154432391638),
#  ('each', 0.55705058772587768),
#  ('losing', 0.55681073700781403),
#  ('heroic', 0.55681073700781403),
#  ('charlie', 0.55675455565439058),
#  ('pal', 0.55628799784274796),
#  ('thoroughly', 0.55603796658753868),
#  ('priceless', 0.55594605904646033),
#  ('pursuit', 0.55594605904646033),
#  ('young', 0.55585622066564677),
#  ('musical', 0.55523941333562377),
#  ('attitude', 0.55431073570572953),
#  ('threat', 0.55431073570572953),
#  ('larger', 0.55338523818478658),
#  ('surprises', 0.55310110691422898),
#  ('redemption', 0.55300054881670346),
#  ('tells', 0.55289128905150331),
#  ('waves', 0.55278982286502287),
#  ('james', 0.55212942990722647),
#  ('dee', 0.55206858230003986),
#  ('odds', 0.55083095837968976),
#  ('reminds', 0.55004633691927196),
#  ('inevitable', 0.55004633691927196),
#  ('striking', 0.55004633691927196),
#  ('relations', 0.55004633691927196),
#  ('epic', 0.54950447833110205),
#  ('pushing', 0.54856595174883771),
#  ('lewis', 0.54783708874281001),
#  ('understanding', 0.54735936709844657),
#  ('personalities', 0.54729530354738209),
#  ('mouse', 0.54729530354738209),
#  ('media', 0.54654370636806993),
#  ('official', 0.5455111817538808),
#  ('defined', 0.54522705048332309),
#  ('newly', 0.54522705048332309),
#  ('albert', 0.54472717544167193),
#  ('complain', 0.54472717544167193),
#  ('visually', 0.54388648602687883),
#  ('genuine', 0.54333490233128523),
#  ('color', 0.54308648598421205),
#  ('position', 0.54286497751060725),
#  ('jesse', 0.54266622962164945),
#  ('tend', 0.54232429082536171),
#  ('faithful', 0.5420406431139152),
#  ('sexuality', 0.54134116769194107),
#  ('falk', 0.54080645597792654),
#  ('jr', 0.54071915404413329),
#  ('hidden', 0.54050139191210733),
#  ('cousin', 0.54012199325442156),
#  ('recently', 0.53930509508785929),
#  ('combination', 0.5389965007326869),
#  ('savage', 0.5389965007326869),
#  ('craven', 0.5389965007326869),
#  ('silence', 0.5389965007326869),
#  ('disc', 0.5389965007326869),
#  ('world', 0.53880879542946103),
#  ('realism', 0.53835029715608063),
#  ('demons', 0.53803818729087538),
#  ('profound', 0.53773307668591508),
#  ('brought', 0.53755453941578579),
#  ('shows', 0.53684519119017482),
#  ('tiger', 0.53680111016925136),
#  ('gangster', 0.53588220360332828),
#  ('life', 0.5357926091338483),
#  ('reveal', 0.53524415111413648),
#  ('dealing', 0.53435612117618481),
#  ('arrives', 0.53311066855542566),
#  ('roy', 0.53302633374618325),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('kareena', -4.6051701859880918),
#  ('tashan', -4.6051701859880918),
#  ('boll', -4.1359153400045967),
#  ('uwe', -3.9874467672453879),
#  ('dahmer', -3.9361205570072064),
#  ('seagal', -3.4299654518385978),
#  ('stinker', -3.193994158491464),
#  ('dillinger', -3.003684601744486),
#  ('unwatchable', -2.9343461981705814),
#  ('incoherent', -2.7802480378551717),
#  ('timberlake', -2.7454893696188449),
#  ('mst', -2.7248573194185912),
#  ('damme', -2.6174037068808276),
#  ('unfunny', -2.5883146754015347),
#  ('horrid', -2.5873728074194622),
#  ('waste', -2.5332030087737771),
#  ('anil', -2.4868597754088824),
#  ('redeeming', -2.4404593579994862),
#  ('pointless', -2.4171675760252143),
#  ('blah', -2.3676523882692568),
#  ('atrocious', -2.2853040808668683),
#  ('snakes', -2.2685900877413605),
#  ('lousy', -2.249804355779951),
#  ('drivel', -2.2453505785490608),
#  ('laughable', -2.231050722243765),
#  ('tripe', -2.227235655752259),
#  ('worst', -2.2110301894267277),
#  ('embarrassment', -2.1764082652091936),
#  ('wasting', -2.137455936740464),
#  ('awful', -2.1180002383648371)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = {word for word, count in total_counts.items()}

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'cain': 1,
#  'soo': 2,
#  'disown': 3,
#  'hsiao': 4,
#  'intertextuality': 5,
#  'cortney': 6,
#  'shecky': 7,
#  'autumnal': 8,
#  'testi': 9,
#  'feathering': 10,
#  'stillman': 11,
#  'oedpius': 12,
#  'unenthusiastic': 13,
#  'purgatori': 14,
#  'unsaved': 15,
#  'brewsters': 16,
#  'actioneer': 17,
#  'melvil': 18,
#  'fixin': 19,
#  'begrudge': 20,
#  'glued': 21,
#  'narcissism': 22,
#  'slurring': 23,
#  'hypesters': 24,
#  'personalized': 25,
#  'professionalism': 26,
#  'phoebe': 27,
#  'survived': 28,
#  'spitfire': 29,
#  'contriving': 30,
#  'magistral': 31,
#  'knott': 32,
#  'chairperson': 33,
#  'razzies': 34,
#  'moose': 35,
#  'colonised': 36,
#  'felini': 37,
#  'sodomising': 38,
#  'denman': 39,
#  'leech': 40,
#  'shana': 41,
#  'tap': 42,
#  'halprin': 43,
#  'waffling': 44,
#  'pou': 45,
#  'tac': 46,
#  'whup': 47,
#  'salaries': 48,
#  'metro': 49,
#  'hogbottom': 50,
#  'methinks': 51,
#  'grammar': 52,
#  'retromedia': 53,
#  'gauged': 54,
#  'coprophagia': 55,
#  'molecular': 56,
#  'grey': 57,
#  'knieval': 58,
#  'sevizia': 59,
#  'awaits': 60,
#  'assed': 61,
#  'archivist': 62,
#  'compliance': 63,
#  'dismantling': 64,
#  'dalip': 65,
#  'pangs': 66,
#  'wacky': 67,
#  'radius': 68,
#  'hypnotised': 69,
#  'payaso': 70,
#  'scoffs': 71,
#  'lrm': 72,
#  'garland': 73,
#  'eburne': 74,
#  'aeons': 75,
#  'gamboa': 76,
#  'aylmer': 77,
#  'scratchier': 78,
#  'excepting': 79,
#  'grisly': 80,
#  'jayden': 81,
#  'thon': 82,
#  'trespassing': 83,
#  'refresher': 84,
#  'facade': 85,
#  'aegerter': 86,
#  'sawed': 87,
#  'elmer': 88,
#  'macbeal': 89,
#  'mindedness': 90,
#  'saga': 91,
#  'saleem': 92,
#  'arrondissement': 93,
#  'huit': 94,
#  'teamings': 95,
#  'sergej': 96,
#  'vadis': 97,
#  'mangini': 98,
#  'athleticism': 99,
#  'awestruck': 100,
#  'aliens': 101,
#  'aliso': 102,
#  'ramu': 103,
#  'bloodedness': 104,
#  'supremacy': 105,
#  'loan': 106,
#  'sections': 107,
#  'qualifies': 108,
#  'ragnardocks': 109,
#  'athsma': 110,
#  'snuggled': 111,
#  'butchered': 112,
#  'videodisc': 113,
#  'equations': 114,
#  'powerless': 115,
#  'linen': 116,
#  'unrestrainedly': 117,
#  'exact': 118,
#  'ahold': 119,
#  'girldfriends': 120,
#  'claymation': 121,
#  'sightly': 122,
#  'months': 123,
#  'deardon': 124,
#  'hamburg': 125,
#  'liquidated': 126,
#  'darrell': 127,
#  'napa': 128,
#  'reimburse': 129,
#  'rickles': 130,
#  'orchestrates': 131,
#  'anny': 132,
#  'ngassa': 133,
#  'vengence': 134,
#  'everytown': 135,
#  'counselor': 136,
#  'confirming': 137,
#  'replayable': 138,
#  'needed': 139,
#  'manila': 140,
#  'seberg': 141,
#  'mabye': 142,
#  'exaggerating': 143,
#  'ifit': 144,
#  'skid': 145,
#  'callan': 146,
#  'leia': 147,
#  'compete': 148,
#  'wheedling': 149,
#  'doodling': 150,
#  'distantiate': 151,
#  'chimayo': 152,
#  'badgering': 153,
#  'vice': 154,
#  'retard': 155,
#  'coping': 156,
#  'muppets': 157,
#  'freakness': 158,
#  'overflows': 159,
#  'emilio': 160,
#  'envelop': 161,
#  'suspenseless': 162,
#  'advantageous': 163,
#  'dandylion': 164,
#  'haggis': 165,
#  'derby': 166,
#  'woodie': 167,
#  'coleseum': 168,
#  'rewatchability': 169,
#  'movieworld': 170,
#  'hygienist': 171,
#  'immersive': 172,
#  'goldblum': 173,
#  'efw': 174,
#  'ineluctably': 175,
#  'potenta': 176,
#  'usenet': 177,
#  'horrifibly': 178,
#  'tyros': 179,
#  'domesticated': 180,
#  'uplifter': 181,
#  'juggles': 182,
#  'charted': 183,
#  'cosmos': 184,
#  'lisbon': 185,
#  'betsy': 186,
#  'maga': 187,
#  'tires': 188,
#  'melodramatic': 189,
#  'nauseates': 190,
#  'glazing': 191,
#  'salman': 192,
#  'vette': 193,
#  'indestructibility': 194,
#  'swingers': 195,
#  'pretenders': 196,
#  'richie': 197,
#  'sabbatical': 198,
#  'indemnity': 199,
#  'garofolo': 200,
#  'goldbeg': 201,
#  'demonicly': 202,
#  'puerility': 203,
#  'speakeasies': 204,
#  'twisting': 205,
#  'anthropomorphism': 206,
#  'rocketing': 207,
#  'mecca': 208,
#  'babitch': 209,
#  'sharkboy': 210,
#  'minefield': 211,
#  'muchly': 212,
#  'unofficial': 213,
#  'bohbot': 214,
#  'calculation': 215,
#  'xyx': 216,
#  'maelstrm': 217,
#  'tillie': 218,
#  'horroresque': 219,
#  'immediatly': 220,
#  'winked': 221,
#  'dutiful': 222,
#  'hitchcok': 223,
#  'polled': 224,
#  'aiden': 225,
#  'wittier': 226,
#  'mistuharu': 227,
#  'nous': 228,
#  'turteltaub': 229,
#  'cobb': 230,
#  'heartbreakingly': 231,
#  'japanese': 232,
#  'buccaneer': 233,
#  'jugs': 234,
#  'jemison': 235,
#  'unfinished': 236,
#  'specters': 237,
#  'ticonderoga': 238,
#  'gloomy': 239,
#  'arbitrarily': 240,
#  'brainwashed': 241,
#  'schieder': 242,
#  'weaklings': 243,
#  'idleness': 244,
#  'roaming': 245,
#  'humanity': 246,
#  'grasped': 247,
#  'karamzin': 248,
#  'signification': 249,
#  'metty': 250,
#  'bickering': 251,
#  'whizbang': 252,
#  'delegation': 253,
#  'greenthumb': 254,
#  'pertinence': 255,
#  'critiquing': 256,
#  'lovecraftian': 257,
#  'persian': 258,
#  'wigging': 259,
#  'milieu': 260,
#  'ocker': 261,
#  'finneran': 262,
#  'chap': 263,
#  'nilly': 264,
#  'nono': 265,
#  'deveraux': 266,
#  'energetic': 267,
#  'sticks': 268,
#  'vanne': 269,
#  'waverly': 270,
#  'outlandishly': 271,
#  'weaselly': 272,
#  'fellating': 273,
#  'contended': 274,
#  'immerses': 275,
#  'condorwhich': 276,
#  'unequally': 277,
#  'reeks': 278,
#  'sonny': 279,
#  'skulls': 280,
#  'lamps': 281,
#  'bowled': 282,
#  'fruits': 283,
#  'utilizes': 284,
#  'bestbut': 285,
#  'gulping': 286,
#  'sfsu': 287,
#  'gretel': 288,
#  'trainees': 289,
#  'brilliantness': 290,
#  'potentialize': 291,
#  'effects': 292,
#  'river': 293,
#  'cits': 294,
#  'spadafore': 295,
#  'penlope': 296,
#  'overhear': 297,
#  'reteaming': 298,
#  'latterday': 299,
#  'swinson': 300,
#  'gunboat': 301,
#  'yankovic': 302,
#  'georgie': 303,
#  'katy': 304,
#  'vipers': 305,
#  'charmian': 306,
#  'oe': 307,
#  'ladder': 308,
#  'mayo': 309,
#  'subculture': 310,
#  'agust': 311,
#  'grudge': 312,
#  'forks': 313,
#  'latvia': 314,
#  'kinzer': 315,
#  'graph': 316,
#  'bunce': 317,
#  'mycenaean': 318,
#  'conflict': 319,
#  'lenka': 320,
#  'oom': 321,
#  'lindbergh': 322,
#  'eugenic': 323,
#  'unbuckles': 324,
#  'pergado': 325,
#  'mischievous': 326,
#  'scanning': 327,
#  'overuse': 328,
#  'conclude': 329,
#  'addicting': 330,
#  'burlesqued': 331,
#  'draughtswoman': 332,
#  'potyomkin': 333,
#  'labyrinthian': 334,
#  'embattled': 335,
#  'nonlds': 336,
#  'diminish': 337,
#  'bte': 338,
#  'unimportant': 339,
#  'crispen': 340,
#  'tugger': 341,
#  'stracultr': 342,
#  'manifestation': 343,
#  'blatch': 344,
#  'newth': 345,
#  'munitions': 346,
#  'meg': 347,
#  'lazerov': 348,
#  'incase': 349,
#  'cocoons': 350,
#  'undercut': 351,
#  'petunias': 352,
#  'enhancements': 353,
#  'accident': 354,
#  'natsu': 355,
#  'proposing': 356,
#  'giff': 357,
#  'waiter': 358,
#  'servents': 359,
#  'abyssmal': 360,
#  'proposed': 361,
#  'coincided': 362,
#  'kevnjeff': 363,
#  'bohemian': 364,
#  'projected': 365,
#  'lent': 366,
#  'atlanta': 367,
#  'recommendable': 368,
#  'visualizing': 369,
#  'firetrap': 370,
#  'scarier': 371,
#  'telletubbes': 372,
#  'bishoff': 373,
#  'lasky': 374,
#  'hippies': 375,
#  'tsang': 376,
#  'portrays': 377,
#  'picturehe': 378,
#  'chasse': 379,
#  'maddison': 380,
#  'dalmers': 381,
#  'gainsbourgh': 382,
#  'betrayal': 383,
#  'stigmata': 384,
#  'approximate': 385,
#  'travail': 386,
#  'morhenge': 387,
#  'marginalisation': 388,
#  'gq': 389,
#  'harrington': 390,
#  'why': 391,
#  'denied': 392,
#  'dino': 393,
#  'bargearse': 394,
#  'salvatore': 395,
#  'initial': 396,
#  'entirelly': 397,
#  'forwarding': 398,
#  'crafty': 399,
#  'creditable': 400,
#  'demand': 401,
#  'grainy': 402,
#  'villainy': 403,
#  'diversified': 404,
#  'retell': 405,
#  'annual': 406,
#  'brightened': 407,
#  'dystopic': 408,
#  'eisner': 409,
#  'position': 410,
#  'zhongwen': 411,
#  'commissars': 412,
#  'snake': 413,
#  'goer': 414,
#  'indictment': 415,
#  'remo': 416,
#  'overexplanation': 417,
#  'delle': 418,
#  'loathed': 419,
#  'resents': 420,
#  'hellbound': 421,
#  'frida': 422,
#  'bemoaned': 423,
#  'fletcher': 424,
#  'grayscale': 425,
#  'sufficed': 426,
#  'hil': 427,
#  'noncomplicated': 428,
#  'misato': 429,
#  'sopisticated': 430,
#  'gunshot': 431,
#  'winnie': 432,
#  'las': 433,
#  'mallaig': 434,
#  'catherine': 435,
#  'coined': 436,
#  'volition': 437,
#  'wehle': 438,
#  'balta': 439,
#  'ped': 440,
#  'thorstein': 441,
#  'charlus': 442,
#  'kilt': 443,
#  'bundles': 444,
#  'faracy': 445,
#  'filing': 446,
#  'contracter': 447,
#  'butmom': 448,
#  'crippled': 449,
#  'arrangement': 450,
#  'prizzi': 451,
#  'coffey': 452,
#  'acp': 453,
#  'dob': 454,
#  'rapaport': 455,
#  'shows': 456,
#  'pdvsa': 457,
#  'premised': 458,
#  'squeezes': 459,
#  'meekly': 460,
#  'malkovich': 461,
#  'inmho': 462,
#  'sway': 463,
#  'cha': 464,
#  'umpteen': 465,
#  'tin': 466,
#  'zp': 467,
#  'dorms': 468,
#  'evilest': 469,
#  'boosts': 470,
#  'muffin': 471,
#  'pb': 472,
#  'jour': 473,
#  'oppinion': 474,
#  'pontificator': 475,
#  'soule': 476,
#  'spaz': 477,
#  'tequila': 478,
#  'corbetts': 479,
#  'culture': 480,
#  'devotes': 481,
#  'masturbated': 482,
#  'monolithic': 483,
#  'dernier': 484,
#  'booooooooooooooooooooooooooooooooooooooooooooooo': 485,
#  'unabashed': 486,
#  'equating': 487,
#  'mosley': 488,
#  'pooing': 489,
#  'artiness': 490,
#  'myiazaki': 491,
#  'impactive': 492,
#  'motorised': 493,
#  'theroux': 494,
#  'changruputra': 495,
#  'luchi': 496,
#  'blasters': 497,
#  'treacly': 498,
#  'lippo': 499,
#  'rajini': 500,
#  'promting': 501,
#  'insufficient': 502,
#  'aristos': 503,
#  'butcherer': 504,
#  'lookouts': 505,
#  'preferences': 506,
#  'munson': 507,
#  'historically': 508,
#  'secondly': 509,
#  'ayat': 510,
#  'crosseyed': 511,
#  'exasperated': 512,
#  'says': 513,
#  'maguffin': 514,
#  'disfigured': 515,
#  'scaling': 516,
#  'theodorakis': 517,
#  'youji': 518,
#  'herbal': 519,
#  'bystander': 520,
#  'reclamation': 521,
#  'vagaries': 522,
#  'automotive': 523,
#  'competitors': 524,
#  'disturbances': 525,
#  'latitude': 526,
#  'stingers': 527,
#  'symbol': 528,
#  'wherein': 529,
#  'mongolia': 530,
#  'spectators': 531,
#  'longing': 532,
#  'meola': 533,
#  'roussillon': 534,
#  'breathless': 535,
#  'anaconda': 536,
#  'cinematic': 537,
#  'finesse': 538,
#  'disguised': 539,
#  'reprehensible': 540,
#  'memphis': 541,
#  'disused': 542,
#  'bypassing': 543,
#  'touissant': 544,
#  'announcer': 545,
#  'cleaner': 546,
#  'fait': 547,
#  'sher': 548,
#  'particullary': 549,
#  'ankylosaur': 550,
#  'outlined': 551,
#  'thoroughfare': 552,
#  'reunites': 553,
#  'thalman': 554,
#  'snippy': 555,
#  'hypermacho': 556,
#  'ghungroo': 557,
#  'effette': 558,
#  'amores': 559,
#  'tarred': 560,
#  'kitrosser': 561,
#  'hairless': 562,
#  'wassell': 563,
#  'boudoir': 564,
#  'delayed': 565,
#  'slipery': 566,
#  'essandoh': 567,
#  'whatsoever': 568,
#  'relentless': 569,
#  'how': 570,
#  'curdling': 571,
#  'hwd': 572,
#  'mcgonagle': 573,
#  'ubber': 574,
#  'profligate': 575,
#  'scull': 576,
#  'ization': 577,
#  'gunslinging': 578,
#  'ridge': 579,
#  'orally': 580,
#  'stunts': 581,
#  'beck': 582,
#  'shrieking': 583,
#  'fixates': 584,
#  'siana': 585,
#  'spirts': 586,
#  'rambunctious': 587,
#  'ohgo': 588,
#  'cryptozoology': 589,
#  'fos': 590,
#  'extracurricular': 591,
#  'proffers': 592,
#  'papi': 593,
#  'howze': 594,
#  'lamarre': 595,
#  'bryden': 596,
#  'dickie': 597,
#  'externalization': 598,
#  'repulsively': 599,
#  'bust': 600,
#  'enslin': 601,
#  'mchale': 602,
#  'ates': 603,
#  'appointments': 604,
#  'represenative': 605,
#  'stub': 606,
#  'forrester': 607,
#  'clastrophobic': 608,
#  'bozos': 609,
#  'banjo': 610,
#  'chocked': 611,
#  'mopery': 612,
#  'unanticipated': 613,
#  'collage': 614,
#  'lowest': 615,
#  'omniscient': 616,
#  'klicking': 617,
#  'maratonci': 618,
#  'ironsides': 619,
#  'paralleling': 620,
#  'down': 621,
#  'urine': 622,
#  'lonelier': 623,
#  'vcr': 624,
#  'hangover': 625,
#  'mcgill': 626,
#  'understandings': 627,
#  'firth': 628,
#  'spirtas': 629,
#  'dereliction': 630,
#  'necklaces': 631,
#  'neurotics': 632,
#  'airphone': 633,
#  'jong': 634,
#  'riches': 635,
#  'depressants': 636,
#  'furniture': 637,
#  'greist': 638,
#  'saito': 639,
#  'mulholland': 640,
#  'studiously': 641,
#  'ciarin': 642,
#  'gouts': 643,
#  'harker': 644,
#  'benfica': 645,
#  'claudio': 646,
#  'exchanging': 647,
#  'cosmetic': 648,
#  'horoscope': 649,
#  'venoms': 650,
#  'apatow': 651,
#  'ladyhawk': 652,
#  'knotts': 653,
#  'bush': 654,
#  'belgrade': 655,
#  'armpits': 656,
#  'bering': 657,
#  'budding': 658,
#  'kurt': 659,
#  'interred': 660,
#  'padm': 661,
#  'caroline': 662,
#  'opined': 663,
#  'treated': 664,
#  'dictatorships': 665,
#  'credulity': 666,
#  'blackhawk': 667,
#  'lyon': 668,
#  'waitresses': 669,
#  'netting': 670,
#  'implicate': 671,
#  'advani': 672,
#  'barn': 673,
#  'uptade': 674,
#  'ivan': 675,
#  'finishers': 676,
#  'fictional': 677,
#  'sprinkles': 678,
#  'nurplex': 679,
#  'makers': 680,
#  'frustrates': 681,
#  'charade': 682,
#  'barretts': 683,
#  'toed': 684,
#  'leavened': 685,
#  'macabrely': 686,
#  'evolutions': 687,
#  'hampers': 688,
#  'iiiiii': 689,
#  'relics': 690,
#  'morgia': 691,
#  'generating': 692,
#  'ren': 693,
#  'hupert': 694,
#  'squeals': 695,
#  'slovenian': 696,
#  'weis': 697,
#  'disqualify': 698,
#  'insults': 699,
#  'komodo': 700,
#  'erick': 701,
#  'paneled': 702,
#  'prospector': 703,
#  'edouard': 704,
#  'overreacting': 705,
#  'sivajiganeshan': 706,
#  'simira': 707,
#  'latently': 708,
#  'finch': 709,
#  'ua': 710,
#  'dunno': 711,
#  'prsoner': 712,
#  'cratey': 713,
#  'carmack': 714,
#  'bros': 715,
#  'misshappenings': 716,
#  'ebonics': 717,
#  'truncated': 718,
#  'mingled': 719,
#  'sleeker': 720,
#  'fatherly': 721,
#  'greenbush': 722,
#  'clit': 723,
#  'jarmila': 724,
#  'dully': 725,
#  'dvid': 726,
#  'zeb': 727,
#  'lize': 728,
#  'thomason': 729,
#  'goodness': 730,
#  'superstars': 731,
#  'yvonne': 732,
#  'toadying': 733,
#  'sandburgs': 734,
#  'unfamiliarity': 735,
#  'mindlessness': 736,
#  'hartmen': 737,
#  'nbtn': 738,
#  'cuties': 739,
#  'master': 740,
#  'schaech': 741,
#  'moravia': 742,
#  'incurred': 743,
#  'clashes': 744,
#  'totin': 745,
#  'griefs': 746,
#  'infects': 747,
#  'macleod': 748,
#  'delay': 749,
#  'unprovocked': 750,
#  'backula': 751,
#  'emancipated': 752,
#  'leered': 753,
#  'starship': 754,
#  'reviles': 755,
#  'tie': 756,
#  'marvellous': 757,
#  'natch': 758,
#  'oj': 759,
#  'aleksandr': 760,
#  'skinkons': 761,
#  'blessing': 762,
#  'rollnecks': 763,
#  'ia': 764,
#  'choreographs': 765,
#  'liberate': 766,
#  'gladiators': 767,
#  'eeuurrgghh': 768,
#  'pliant': 769,
#  'cocking': 770,
#  'closeup': 771,
#  'helvard': 772,
#  'california': 773,
#  'yvon': 774,
#  'straughan': 775,
#  'faceted': 776,
#  'btchiness': 777,
#  'foolishness': 778,
#  'snaking': 779,
#  'flagitious': 780,
#  'blackblood': 781,
#  'schmo': 782,
#  'fruedian': 783,
#  'nubb': 784,
#  'andrewjlau': 785,
#  'voorhess': 786,
#  'unrest': 787,
#  'being': 788,
#  'qualifications': 789,
#  'appropriated': 790,
#  'customer': 791,
#  'fils': 792,
#  'lagrimas': 793,
#  'gillmore': 794,
#  'stu': 795,
#  'mandala': 796,
#  'mcgovern': 797,
#  'always': 798,
#  'incidental': 799,
#  'plex': 800,
#  'rabbi': 801,
#  'felsh': 802,
#  'moldy': 803,
#  'cries': 804,
#  'unengaging': 805,
#  'torpedo': 806,
#  'karr': 807,
#  'burgandian': 808,
#  'settle': 809,
#  'workdays': 810,
#  'umbrage': 811,
#  'rerunning': 812,
#  'calhern': 813,
#  'athelny': 814,
#  'lambasting': 815,
#  'piles': 816,
#  'fanzines': 817,
#  'blankman': 818,
#  'teensy': 819,
#  'characterizing': 820,
#  'participate': 821,
#  'hadass': 822,
#  'kiley': 823,
#  'unexplainably': 824,
#  'waved': 825,
#  'roscoe': 826,
#  'shaved': 827,
#  'avionics': 828,
#  'decides': 829,
#  'siobhan': 830,
#  'outings': 831,
#  'addam': 832,
#  'blackballed': 833,
#  'doorman': 834,
#  'frauleins': 835,
#  'iraqis': 836,
#  'scriptedness': 837,
#  'pixie': 838,
#  'barthlmy': 839,
#  'satan': 840,
#  'downwind': 841,
#  'stormed': 842,
#  'charles': 843,
#  'crazy': 844,
#  'buddhism': 845,
#  'simpleminded': 846,
#  'styled': 847,
#  'seena': 848,
#  'feist': 849,
#  'srbljanovic': 850,
#  'tolerates': 851,
#  'suliban': 852,
#  'shaw': 853,
#  'scanners': 854,
#  'gegen': 855,
#  'echoed': 856,
#  'sinister': 857,
#  'dissect': 858,
#  'truckers': 859,
#  'yehweh': 860,
#  'sheiner': 861,
#  'unclad': 862,
#  'gut': 863,
#  'barabas': 864,
#  'mankiewicz': 865,
#  'tumhe': 866,
#  'assign': 867,
#  'ragona': 868,
#  'ain': 869,
#  'coronation': 870,
#  'diligent': 871,
#  'naps': 872,
#  'vicadin': 873,
#  'wanking': 874,
#  'cabells': 875,
#  'umptieth': 876,
#  'eurasia': 877,
#  'tsubaki': 878,
#  'causeway': 879,
#  'lander': 880,
#  'pars': 881,
#  'briss': 882,
#  'precociousness': 883,
#  'mandylor': 884,
#  'virgins': 885,
#  'likened': 886,
#  'haliburton': 887,
#  'saxe': 888,
#  'mosquito': 889,
#  'thereof': 890,
#  'lucky': 891,
#  'pillars': 892,
#  'melandez': 893,
#  'bluff': 894,
#  'diplomas': 895,
#  'mannheim': 896,
#  'spacek': 897,
#  'lds': 898,
#  'casings': 899,
#  'dell': 900,
#  'downfalls': 901,
#  'generatively': 902,
#  'bereft': 903,
#  'biblical': 904,
#  'denigration': 905,
#  'rotne': 906,
#  'reognise': 907,
#  'newsom': 908,
#  'ostfront': 909,
#  'duping': 910,
#  'infiltration': 911,
#  'targetted': 912,
#  'clunks': 913,
#  'underprivilegded': 914,
#  'forefinger': 915,
#  'reliable': 916,
#  'greenwich': 917,
#  'outweighs': 918,
#  'elizabethtown': 919,
#  'fathom': 920,
#  'concluding': 921,
#  'vacationing': 922,
#  'spindles': 923,
#  'chuk': 924,
#  'petites': 925,
#  'banton': 926,
#  'dekhne': 927,
#  'westland': 928,
#  'lazar': 929,
#  'meditation': 930,
#  'departmentthe': 931,
#  'paoli': 932,
#  'slogs': 933,
#  'encyclopedic': 934,
#  'jerilderie': 935,
#  'harlot': 936,
#  'ministrations': 937,
#  'pianiste': 938,
#  'zooey': 939,
#  'giroux': 940,
#  'propoghanda': 941,
#  'excempt': 942,
#  'krush': 943,
#  'biggies': 944,
#  'roosevelt': 945,
#  'clipboards': 946,
#  'max': 947,
#  'candle': 948,
#  'chutzpah': 949,
#  'merchandising': 950,
#  'dinocroc': 951,
#  'bb': 952,
#  'symmetrical': 953,
#  'smirker': 954,
#  'farrago': 955,
#  'shawshank': 956,
#  'stamina': 957,
#  'ttss': 958,
#  'patients': 959,
#  'cranky': 960,
#  'grandchildren': 961,
#  'runners': 962,
#  'disc': 963,
#  'design': 964,
#  'slicing': 965,
#  'luc': 966,
#  'rupturing': 967,
#  's': 968,
#  'incubation': 969,
#  'scholes': 970,
#  'mindhunters': 971,
#  'rolling': 972,
#  'buyruk': 973,
#  'brazzi': 974,
#  'sweeet': 975,
#  'aristotle': 976,
#  'gollam': 977,
#  'unusal': 978,
#  'frostbite': 979,
#  'comprise': 980,
#  'halliday': 981,
#  'squaw': 982,
#  'sempergratis': 983,
#  'craydon': 984,
#  'fantastico': 985,
#  'leza': 986,
#  'distant': 987,
#  'bodybag': 988,
#  'mccomb': 989,
#  'floyd': 990,
#  'rennie': 991,
#  'banquo': 992,
#  'arabs': 993,
#  'sevalas': 994,
#  'ranee': 995,
#  'committed': 996,
#  'trackings': 997,
#  'necessitates': 998,
#  'elfriede': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    return 1 if label == "POSITIVE" else 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        for i,word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
        for i,label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes, self.hidden_nodes))
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        self.layer_0 *= 0
        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
        
        
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        return 1 if label == "POSITIVE" else 0
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        return 1/(1+np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid fucntion 
        return output * (1 - output)

    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            
            # Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            
             
            
            if(layer_2 >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(layer_2 < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1

            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process.    
                
            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        # Return POSITIVE for values above greater-than-or-equal-to 0.5 in the output layer;
        # return NEGATIVE for other values
        
        if(layer_2[0] >= 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:16.9% Speed(reviews/sec):838.0 #Correct:85 #Tested:170 Testing Accuracy:50.0%
# Progress:37.8% Speed(reviews/sec):928.3 #Correct:190 #Tested:379 Testing Accuracy:50.1%
# Progress:58.3% Speed(reviews/sec):955.7 #Correct:292 #Tested:584 Testing Accuracy:50.0%
# Progress:82.5% Speed(reviews/sec):1009. #Correct:413 #Tested:826 Testing Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):1027. #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:5.7% Speed(reviews/sec):119.9 #Correct:685 #Trained:1369 Training Accuracy:50.0%%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-ad0ddebea879> in <module>()
# ----> 1 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-55-2511f810f154> in train(self, training_reviews, training_labels)
#     182             # Update the weights
#     183             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 184             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     185
#     186
#
# KeyboardInterrupt:

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:1.83% Speed(reviews/sec):68.33 #Correct:221 #Trained:442 Training Accuracy:50.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-6f725220b326> in <module>()
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-55-2511f810f154> in train(self, training_reviews, training_labels)
#     157             #       but use the sigmoid activation function for the output layer.
#     158
# --> 159             self.update_input_layer(review)
#     160
#     161             # Hidden layer
#
# <ipython-input-55-2511f810f154> in update_input_layer(self, review)
#     109             #       with raise an exception in Python. This allows us to ignore unknown
#     110             #       words encountered in new reviews.
# --> 111             if(word in self.word2index.keys()):
#     112                 self.layer_0[0][self.word2index[word]] += 1
#     113
#
# KeyboardInterrupt:

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:3.40% Speed(reviews/sec):57.98 #Correct:410 #Trained:819 Training Accuracy:50.0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-1005528b3ae1> in <module>()
#       1 mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
# ----> 2 mlp.train(reviews[:-1000],labels[:-1000])
#
# <ipython-input-55-2511f810f154> in train(self, training_reviews, training_labels)
#     182             # Update the weights
#     183             self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
# --> 184             self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step
#     185
#     186
#
# KeyboardInterrupt:

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()
# Out:
# [('.', 27),
#  ('', 18),
#  ('the', 9),
#  ('to', 6),
#  ('high', 5),
#  ('i', 5),
#  ('bromwell', 4),
#  ('is', 4),
#  ('a', 4),
#  ('teachers', 4),
#  ('that', 4),
#  ('of', 4),
#  ('it', 2),
#  ('at', 2),
#  ('as', 2),
#  ('school', 2),
#  ('my', 2),
#  ('in', 2),
#  ('me', 2),
#  ('students', 2),
#  ('their', 2),
#  ('student', 2),
#  ('cartoon', 1),
#  ('comedy', 1),
#  ('ran', 1),
#  ('same', 1),
#  ('time', 1),
#  ('some', 1),
#  ('other', 1),
#  ('programs', 1),
#  ('about', 1),
#  ('life', 1),
#  ('such', 1),
#  ('years', 1),
#  ('teaching', 1),
#  ('profession', 1),
#  ('lead', 1),
#  ('believe', 1),
#  ('s', 1),
#  ('satire', 1),
#  ('much', 1),
#  ('closer', 1),
#  ('reality', 1),
#  ('than', 1),
#  ('scramble', 1),
#  ('survive', 1),
#  ('financially', 1),
#  ('insightful', 1),
#  ('who', 1),
#  ('can', 1),
#  ('see', 1),
#  ('right', 1),
#  ('through', 1),
#  ('pathetic', 1),
#  ('pomp', 1),
#  ('pettiness', 1),
#  ('whole', 1),
#  ('situation', 1),
#  ('all', 1),
#  ('remind', 1),
#  ('schools', 1),
#  ('knew', 1),
#  ('and', 1),
#  ('when', 1),
#  ('saw', 1),
#  ('episode', 1),
#  ('which', 1),
#  ('repeatedly', 1),
#  ('tried', 1),
#  ('burn', 1),
#  ('down', 1),
#  ('immediately', 1),
#  ('recalled', 1),
#  ('classic', 1),
#  ('line', 1),
#  ('inspector', 1),
#  ('m', 1),
#  ('here', 1),
#  ('sack', 1),
#  ('one', 1),
#  ('your', 1),
#  ('welcome', 1),
#  ('expect', 1),
#  ('many', 1),
#  ('adults', 1),
#  ('age', 1),
#  ('think', 1),
#  ('far', 1),
#  ('fetched', 1),
#  ('what', 1),
#  ('pity', 1),
#  ('isn', 1),
#  ('t', 1)]

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize))

p.scatter(x="x1", y="x2", size=8, source=source,color=colors_list)

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
